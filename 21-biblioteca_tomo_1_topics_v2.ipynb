# %% [markdown]
# # Tomo 1

# %%
import os
from collections import Counter, defaultdict
from string import punctuation

import nltk
import numpy as np
from gensim import corpora, models
from nltk.corpus import stopwords
from scipy import spatial

# %% [markdown]
# ## Loading data

# %%
def key_sort_files(x):
    return int(x[:-4].split('-')[0])

path = 'data/aux/biblioteca/text_parts/1/'
unsorted_file_list = [filename for filename in os.listdir(path) if filename.endswith('.txt')]
file_list = sorted(unsorted_file_list, key=key_sort_files)

raw_texts = []
for filename in file_list:
    with open(path + filename) as f:
        raw_texts.append(f.read())

# %% [markdown]
# ## Cleaning data

# %%
chars = []
for text in raw_texts:
    for c in text:
        if not c.isalnum():
            chars.append(c)

# %%
characters = set(chars)

# %%
with open('data/stopwords/spanish_stopwords.txt') as f:
    sp_stopwords = list(set(map(str.strip, f.readlines())))

with open('data/stopwords/my_stopwords.txt') as f:
    my_stopwords = list(set(map(str.strip, f.readlines())))

stop = stopwords.words('spanish') + sp_stopwords + my_stopwords + list(punctuation) + list(characters)

# %%
def clean(s):
    r = s.lower().strip()
    for c in characters:
        r = r.replace(c, ' ')
    r = r.replace('farc ep', 'farc-ep')
    r = r.replace('confianz a', 'confianza')
    r = r.replace('cons trucción', 'construcción')
    rs = [w for w in nltk.word_tokenize(r) if w not in stop and len(w) > 2 and not w.isdecimal()]
    r = ' '.join(rs)
    return r

# %%
cleaned_texts = [clean(text) for text in raw_texts]

# %%
char_counter = defaultdict(int)
for c in characters:
    for text in cleaned_texts:
        if c in text:
            char_counter[c]+=text.count(c)
char_counter
# Out:
# defaultdict(int, {' ': 37776, '-': 417})

# %% [markdown]
# ## Preparing data

# %%
documents = cleaned_texts

# %%
document = ' '.join(documents)

# %%
# Only texts that contain MORE THAN or EQUALS TO 100 words
texts = [[word for word in document.split()] for document in documents if len(document.split()) >= 100]

# %%
len(texts)
# Out:
# 35

# %%
dictionary = corpora.Dictionary(texts)

# %%
len(dictionary)
# Out:
# 8832

# %% [markdown]
# ## Processing data

# %%
# %%time

RS = 3

lsi_topics_lst = []
lda_topics_lst = []
hdp_topics_lst = []

MIN_DFs = [1, 2, 4, 7]
MAX_DFs = [0.6, 0.7, 0.8, 0.9]
MAX_FTs = [100, 1000, len(dictionary)]
N_TOPICSs = [4, 10, 35, 100]

total_iterations = len(MIN_DFs) * len(MAX_DFs) * len(MAX_FTs) * len(N_TOPICSs)
iteration = 1
for MIN_DF in MIN_DFs:
    for MAX_DF in MAX_DFs:
        for MAX_FT in MAX_FTs:
            dictionary = corpora.Dictionary(texts)
            dictionary.filter_extremes(no_below=MIN_DF, no_above=MAX_DF, keep_n=MAX_FT)
            corpus = [dictionary.doc2bow(text) for text in texts]
            tfidf = models.TfidfModel(corpus)
            corpus_tfidf = tfidf[corpus]
            
            for N_TOPICS in N_TOPICSs:
                print('Iteration: {} / {}'.format(iteration, total_iterations), \
                      '- MIN_DF:', MIN_DF, '- MAX_DF:', MAX_DF, '- MAX_FT:', MAX_FT, '- N_TOPICS:', N_TOPICS)
                iteration += 1
                
                # LSI
#                 lsi = models.LsiModel(corpus_tfidf, id2word=dictionary, num_topics=N_TOPICS)
#                 corpus_lsi = lsi[corpus_tfidf]
#                 ts = lsi.show_topics(lsi.num_topics, formatted=False)
#                 result = (ts, (MIN_DF, MAX_DF, MAX_FT, N_TOPICS), corpus_lsi)
#                 lsi_topics_lst.append(result)
            
                # LDA
                lda = models.LdaModel(corpus, id2word=dictionary, num_topics=N_TOPICS, random_state=RS)
                corpus_lda = lda[corpus]
                ts = sorted(lda.show_topics(lda.num_topics, formatted=False))
                result = (ts, (MIN_DF, MAX_DF, MAX_FT, N_TOPICS), corpus_lda)
                lda_topics_lst.append(result)
            
                # HDP
                hdp = models.HdpModel(corpus, id2word=dictionary, random_state=RS)
                corpus_hdp = hdp[corpus]
                ts = hdp.show_topics(N_TOPICS, num_words=10, formatted=False)
                result = (ts, (MIN_DF, MAX_DF, MAX_FT, N_TOPICS), corpus_hdp)
                hdp_topics_lst.append(result)
# Out:
# Iteration: 1 / 192 - MIN_DF: 1 - MAX_DF: 0.6 - MAX_FT: 100 - N_TOPICS: 4
# Iteration: 2 / 192 - MIN_DF: 1 - MAX_DF: 0.6 - MAX_FT: 100 - N_TOPICS: 10
# Iteration: 3 / 192 - MIN_DF: 1 - MAX_DF: 0.6 - MAX_FT: 100 - N_TOPICS: 35
# Iteration: 4 / 192 - MIN_DF: 1 - MAX_DF: 0.6 - MAX_FT: 100 - N_TOPICS: 100
# Iteration: 5 / 192 - MIN_DF: 1 - MAX_DF: 0.6 - MAX_FT: 1000 - N_TOPICS: 4
# Iteration: 6 / 192 - MIN_DF: 1 - MAX_DF: 0.6 - MAX_FT: 1000 - N_TOPICS: 10
# Iteration: 7 / 192 - MIN_DF: 1 - MAX_DF: 0.6 - MAX_FT: 1000 - N_TOPICS: 35
# Iteration: 8 / 192 - MIN_DF: 1 - MAX_DF: 0.6 - MAX_FT: 1000 - N_TOPICS: 100
# Iteration: 9 / 192 - MIN_DF: 1 - MAX_DF: 0.6 - MAX_FT: 8832 - N_TOPICS: 4
# Iteration: 10 / 192 - MIN_DF: 1 - MAX_DF: 0.6 - MAX_FT: 8832 - N_TOPICS: 10
# Iteration: 11 / 192 - MIN_DF: 1 - MAX_DF: 0.6 - MAX_FT: 8832 - N_TOPICS: 35
# Iteration: 12 / 192 - MIN_DF: 1 - MAX_DF: 0.6 - MAX_FT: 8832 - N_TOPICS: 100
# Iteration: 13 / 192 - MIN_DF: 1 - MAX_DF: 0.7 - MAX_FT: 100 - N_TOPICS: 4
# Iteration: 14 / 192 - MIN_DF: 1 - MAX_DF: 0.7 - MAX_FT: 100 - N_TOPICS: 10
# Iteration: 15 / 192 - MIN_DF: 1 - MAX_DF: 0.7 - MAX_FT: 100 - N_TOPICS: 35
# Iteration: 16 / 192 - MIN_DF: 1 - MAX_DF: 0.7 - MAX_FT: 100 - N_TOPICS: 100
# Iteration: 17 / 192 - MIN_DF: 1 - MAX_DF: 0.7 - MAX_FT: 1000 - N_TOPICS: 4
# Iteration: 18 / 192 - MIN_DF: 1 - MAX_DF: 0.7 - MAX_FT: 1000 - N_TOPICS: 10
# Iteration: 19 / 192 - MIN_DF: 1 - MAX_DF: 0.7 - MAX_FT: 1000 - N_TOPICS: 35
# Iteration: 20 / 192 - MIN_DF: 1 - MAX_DF: 0.7 - MAX_FT: 1000 - N_TOPICS: 100
# Iteration: 21 / 192 - MIN_DF: 1 - MAX_DF: 0.7 - MAX_FT: 8832 - N_TOPICS: 4
# Iteration: 22 / 192 - MIN_DF: 1 - MAX_DF: 0.7 - MAX_FT: 8832 - N_TOPICS: 10
# Iteration: 23 / 192 - MIN_DF: 1 - MAX_DF: 0.7 - MAX_FT: 8832 - N_TOPICS: 35
# Iteration: 24 / 192 - MIN_DF: 1 - MAX_DF: 0.7 - MAX_FT: 8832 - N_TOPICS: 100
# Iteration: 25 / 192 - MIN_DF: 1 - MAX_DF: 0.8 - MAX_FT: 100 - N_TOPICS: 4
# Iteration: 26 / 192 - MIN_DF: 1 - MAX_DF: 0.8 - MAX_FT: 100 - N_TOPICS: 10
# Iteration: 27 / 192 - MIN_DF: 1 - MAX_DF: 0.8 - MAX_FT: 100 - N_TOPICS: 35
# Iteration: 28 / 192 - MIN_DF: 1 - MAX_DF: 0.8 - MAX_FT: 100 - N_TOPICS: 100
# Iteration: 29 / 192 - MIN_DF: 1 - MAX_DF: 0.8 - MAX_FT: 1000 - N_TOPICS: 4
# Iteration: 30 / 192 - MIN_DF: 1 - MAX_DF: 0.8 - MAX_FT: 1000 - N_TOPICS: 10
# Iteration: 31 / 192 - MIN_DF: 1 - MAX_DF: 0.8 - MAX_FT: 1000 - N_TOPICS: 35
# Iteration: 32 / 192 - MIN_DF: 1 - MAX_DF: 0.8 - MAX_FT: 1000 - N_TOPICS: 100
# Iteration: 33 / 192 - MIN_DF: 1 - MAX_DF: 0.8 - MAX_FT: 8832 - N_TOPICS: 4
# Iteration: 34 / 192 - MIN_DF: 1 - MAX_DF: 0.8 - MAX_FT: 8832 - N_TOPICS: 10
# Iteration: 35 / 192 - MIN_DF: 1 - MAX_DF: 0.8 - MAX_FT: 8832 - N_TOPICS: 35
# Iteration: 36 / 192 - MIN_DF: 1 - MAX_DF: 0.8 - MAX_FT: 8832 - N_TOPICS: 100
# Iteration: 37 / 192 - MIN_DF: 1 - MAX_DF: 0.9 - MAX_FT: 100 - N_TOPICS: 4
# Iteration: 38 / 192 - MIN_DF: 1 - MAX_DF: 0.9 - MAX_FT: 100 - N_TOPICS: 10
# Iteration: 39 / 192 - MIN_DF: 1 - MAX_DF: 0.9 - MAX_FT: 100 - N_TOPICS: 35
# Iteration: 40 / 192 - MIN_DF: 1 - MAX_DF: 0.9 - MAX_FT: 100 - N_TOPICS: 100
# Iteration: 41 / 192 - MIN_DF: 1 - MAX_DF: 0.9 - MAX_FT: 1000 - N_TOPICS: 4
# Iteration: 42 / 192 - MIN_DF: 1 - MAX_DF: 0.9 - MAX_FT: 1000 - N_TOPICS: 10
# Iteration: 43 / 192 - MIN_DF: 1 - MAX_DF: 0.9 - MAX_FT: 1000 - N_TOPICS: 35
# Iteration: 44 / 192 - MIN_DF: 1 - MAX_DF: 0.9 - MAX_FT: 1000 - N_TOPICS: 100
# Iteration: 45 / 192 - MIN_DF: 1 - MAX_DF: 0.9 - MAX_FT: 8832 - N_TOPICS: 4
# Iteration: 46 / 192 - MIN_DF: 1 - MAX_DF: 0.9 - MAX_FT: 8832 - N_TOPICS: 10
# Iteration: 47 / 192 - MIN_DF: 1 - MAX_DF: 0.9 - MAX_FT: 8832 - N_TOPICS: 35
# Iteration: 48 / 192 - MIN_DF: 1 - MAX_DF: 0.9 - MAX_FT: 8832 - N_TOPICS: 100
# Iteration: 49 / 192 - MIN_DF: 2 - MAX_DF: 0.6 - MAX_FT: 100 - N_TOPICS: 4
# Iteration: 50 / 192 - MIN_DF: 2 - MAX_DF: 0.6 - MAX_FT: 100 - N_TOPICS: 10
# Iteration: 51 / 192 - MIN_DF: 2 - MAX_DF: 0.6 - MAX_FT: 100 - N_TOPICS: 35
# Iteration: 52 / 192 - MIN_DF: 2 - MAX_DF: 0.6 - MAX_FT: 100 - N_TOPICS: 100
# Iteration: 53 / 192 - MIN_DF: 2 - MAX_DF: 0.6 - MAX_FT: 1000 - N_TOPICS: 4
# Iteration: 54 / 192 - MIN_DF: 2 - MAX_DF: 0.6 - MAX_FT: 1000 - N_TOPICS: 10
# Iteration: 55 / 192 - MIN_DF: 2 - MAX_DF: 0.6 - MAX_FT: 1000 - N_TOPICS: 35
# Iteration: 56 / 192 - MIN_DF: 2 - MAX_DF: 0.6 - MAX_FT: 1000 - N_TOPICS: 100
# Iteration: 57 / 192 - MIN_DF: 2 - MAX_DF: 0.6 - MAX_FT: 8832 - N_TOPICS: 4
# Iteration: 58 / 192 - MIN_DF: 2 - MAX_DF: 0.6 - MAX_FT: 8832 - N_TOPICS: 10
# Iteration: 59 / 192 - MIN_DF: 2 - MAX_DF: 0.6 - MAX_FT: 8832 - N_TOPICS: 35
# Iteration: 60 / 192 - MIN_DF: 2 - MAX_DF: 0.6 - MAX_FT: 8832 - N_TOPICS: 100
# Iteration: 61 / 192 - MIN_DF: 2 - MAX_DF: 0.7 - MAX_FT: 100 - N_TOPICS: 4
# Iteration: 62 / 192 - MIN_DF: 2 - MAX_DF: 0.7 - MAX_FT: 100 - N_TOPICS: 10
# Iteration: 63 / 192 - MIN_DF: 2 - MAX_DF: 0.7 - MAX_FT: 100 - N_TOPICS: 35
# Iteration: 64 / 192 - MIN_DF: 2 - MAX_DF: 0.7 - MAX_FT: 100 - N_TOPICS: 100
# Iteration: 65 / 192 - MIN_DF: 2 - MAX_DF: 0.7 - MAX_FT: 1000 - N_TOPICS: 4
# Iteration: 66 / 192 - MIN_DF: 2 - MAX_DF: 0.7 - MAX_FT: 1000 - N_TOPICS: 10
# Iteration: 67 / 192 - MIN_DF: 2 - MAX_DF: 0.7 - MAX_FT: 1000 - N_TOPICS: 35
# Iteration: 68 / 192 - MIN_DF: 2 - MAX_DF: 0.7 - MAX_FT: 1000 - N_TOPICS: 100
# Iteration: 69 / 192 - MIN_DF: 2 - MAX_DF: 0.7 - MAX_FT: 8832 - N_TOPICS: 4
# Iteration: 70 / 192 - MIN_DF: 2 - MAX_DF: 0.7 - MAX_FT: 8832 - N_TOPICS: 10
# Iteration: 71 / 192 - MIN_DF: 2 - MAX_DF: 0.7 - MAX_FT: 8832 - N_TOPICS: 35
# Iteration: 72 / 192 - MIN_DF: 2 - MAX_DF: 0.7 - MAX_FT: 8832 - N_TOPICS: 100
# Iteration: 73 / 192 - MIN_DF: 2 - MAX_DF: 0.8 - MAX_FT: 100 - N_TOPICS: 4
# Iteration: 74 / 192 - MIN_DF: 2 - MAX_DF: 0.8 - MAX_FT: 100 - N_TOPICS: 10
# Iteration: 75 / 192 - MIN_DF: 2 - MAX_DF: 0.8 - MAX_FT: 100 - N_TOPICS: 35
# Iteration: 76 / 192 - MIN_DF: 2 - MAX_DF: 0.8 - MAX_FT: 100 - N_TOPICS: 100
# Iteration: 77 / 192 - MIN_DF: 2 - MAX_DF: 0.8 - MAX_FT: 1000 - N_TOPICS: 4
# Iteration: 78 / 192 - MIN_DF: 2 - MAX_DF: 0.8 - MAX_FT: 1000 - N_TOPICS: 10
# Iteration: 79 / 192 - MIN_DF: 2 - MAX_DF: 0.8 - MAX_FT: 1000 - N_TOPICS: 35
# Iteration: 80 / 192 - MIN_DF: 2 - MAX_DF: 0.8 - MAX_FT: 1000 - N_TOPICS: 100
# Iteration: 81 / 192 - MIN_DF: 2 - MAX_DF: 0.8 - MAX_FT: 8832 - N_TOPICS: 4
# Iteration: 82 / 192 - MIN_DF: 2 - MAX_DF: 0.8 - MAX_FT: 8832 - N_TOPICS: 10
# Iteration: 83 / 192 - MIN_DF: 2 - MAX_DF: 0.8 - MAX_FT: 8832 - N_TOPICS: 35
# Iteration: 84 / 192 - MIN_DF: 2 - MAX_DF: 0.8 - MAX_FT: 8832 - N_TOPICS: 100
# Iteration: 85 / 192 - MIN_DF: 2 - MAX_DF: 0.9 - MAX_FT: 100 - N_TOPICS: 4
# Iteration: 86 / 192 - MIN_DF: 2 - MAX_DF: 0.9 - MAX_FT: 100 - N_TOPICS: 10
# Iteration: 87 / 192 - MIN_DF: 2 - MAX_DF: 0.9 - MAX_FT: 100 - N_TOPICS: 35
# Iteration: 88 / 192 - MIN_DF: 2 - MAX_DF: 0.9 - MAX_FT: 100 - N_TOPICS: 100
# Iteration: 89 / 192 - MIN_DF: 2 - MAX_DF: 0.9 - MAX_FT: 1000 - N_TOPICS: 4
# Iteration: 90 / 192 - MIN_DF: 2 - MAX_DF: 0.9 - MAX_FT: 1000 - N_TOPICS: 10
# Iteration: 91 / 192 - MIN_DF: 2 - MAX_DF: 0.9 - MAX_FT: 1000 - N_TOPICS: 35
# Iteration: 92 / 192 - MIN_DF: 2 - MAX_DF: 0.9 - MAX_FT: 1000 - N_TOPICS: 100
# Iteration: 93 / 192 - MIN_DF: 2 - MAX_DF: 0.9 - MAX_FT: 8832 - N_TOPICS: 4
# Iteration: 94 / 192 - MIN_DF: 2 - MAX_DF: 0.9 - MAX_FT: 8832 - N_TOPICS: 10
# Iteration: 95 / 192 - MIN_DF: 2 - MAX_DF: 0.9 - MAX_FT: 8832 - N_TOPICS: 35
# Iteration: 96 / 192 - MIN_DF: 2 - MAX_DF: 0.9 - MAX_FT: 8832 - N_TOPICS: 100
# Iteration: 97 / 192 - MIN_DF: 4 - MAX_DF: 0.6 - MAX_FT: 100 - N_TOPICS: 4
# Iteration: 98 / 192 - MIN_DF: 4 - MAX_DF: 0.6 - MAX_FT: 100 - N_TOPICS: 10
# Iteration: 99 / 192 - MIN_DF: 4 - MAX_DF: 0.6 - MAX_FT: 100 - N_TOPICS: 35
# Iteration: 100 / 192 - MIN_DF: 4 - MAX_DF: 0.6 - MAX_FT: 100 - N_TOPICS: 100
# Iteration: 101 / 192 - MIN_DF: 4 - MAX_DF: 0.6 - MAX_FT: 1000 - N_TOPICS: 4
# Iteration: 102 / 192 - MIN_DF: 4 - MAX_DF: 0.6 - MAX_FT: 1000 - N_TOPICS: 10
# Iteration: 103 / 192 - MIN_DF: 4 - MAX_DF: 0.6 - MAX_FT: 1000 - N_TOPICS: 35
# Iteration: 104 / 192 - MIN_DF: 4 - MAX_DF: 0.6 - MAX_FT: 1000 - N_TOPICS: 100
# Iteration: 105 / 192 - MIN_DF: 4 - MAX_DF: 0.6 - MAX_FT: 8832 - N_TOPICS: 4
# Iteration: 106 / 192 - MIN_DF: 4 - MAX_DF: 0.6 - MAX_FT: 8832 - N_TOPICS: 10
# Iteration: 107 / 192 - MIN_DF: 4 - MAX_DF: 0.6 - MAX_FT: 8832 - N_TOPICS: 35
# Iteration: 108 / 192 - MIN_DF: 4 - MAX_DF: 0.6 - MAX_FT: 8832 - N_TOPICS: 100
# Iteration: 109 / 192 - MIN_DF: 4 - MAX_DF: 0.7 - MAX_FT: 100 - N_TOPICS: 4
# Iteration: 110 / 192 - MIN_DF: 4 - MAX_DF: 0.7 - MAX_FT: 100 - N_TOPICS: 10
# Iteration: 111 / 192 - MIN_DF: 4 - MAX_DF: 0.7 - MAX_FT: 100 - N_TOPICS: 35
# Iteration: 112 / 192 - MIN_DF: 4 - MAX_DF: 0.7 - MAX_FT: 100 - N_TOPICS: 100
# Iteration: 113 / 192 - MIN_DF: 4 - MAX_DF: 0.7 - MAX_FT: 1000 - N_TOPICS: 4
# Iteration: 114 / 192 - MIN_DF: 4 - MAX_DF: 0.7 - MAX_FT: 1000 - N_TOPICS: 10
# Iteration: 115 / 192 - MIN_DF: 4 - MAX_DF: 0.7 - MAX_FT: 1000 - N_TOPICS: 35
# Iteration: 116 / 192 - MIN_DF: 4 - MAX_DF: 0.7 - MAX_FT: 1000 - N_TOPICS: 100
# Iteration: 117 / 192 - MIN_DF: 4 - MAX_DF: 0.7 - MAX_FT: 8832 - N_TOPICS: 4
# Iteration: 118 / 192 - MIN_DF: 4 - MAX_DF: 0.7 - MAX_FT: 8832 - N_TOPICS: 10
# Iteration: 119 / 192 - MIN_DF: 4 - MAX_DF: 0.7 - MAX_FT: 8832 - N_TOPICS: 35
# Iteration: 120 / 192 - MIN_DF: 4 - MAX_DF: 0.7 - MAX_FT: 8832 - N_TOPICS: 100
# Iteration: 121 / 192 - MIN_DF: 4 - MAX_DF: 0.8 - MAX_FT: 100 - N_TOPICS: 4
# Iteration: 122 / 192 - MIN_DF: 4 - MAX_DF: 0.8 - MAX_FT: 100 - N_TOPICS: 10
# Iteration: 123 / 192 - MIN_DF: 4 - MAX_DF: 0.8 - MAX_FT: 100 - N_TOPICS: 35
# Iteration: 124 / 192 - MIN_DF: 4 - MAX_DF: 0.8 - MAX_FT: 100 - N_TOPICS: 100
# Iteration: 125 / 192 - MIN_DF: 4 - MAX_DF: 0.8 - MAX_FT: 1000 - N_TOPICS: 4
# Iteration: 126 / 192 - MIN_DF: 4 - MAX_DF: 0.8 - MAX_FT: 1000 - N_TOPICS: 10
# Iteration: 127 / 192 - MIN_DF: 4 - MAX_DF: 0.8 - MAX_FT: 1000 - N_TOPICS: 35
# Iteration: 128 / 192 - MIN_DF: 4 - MAX_DF: 0.8 - MAX_FT: 1000 - N_TOPICS: 100
# Iteration: 129 / 192 - MIN_DF: 4 - MAX_DF: 0.8 - MAX_FT: 8832 - N_TOPICS: 4
# Iteration: 130 / 192 - MIN_DF: 4 - MAX_DF: 0.8 - MAX_FT: 8832 - N_TOPICS: 10
# Iteration: 131 / 192 - MIN_DF: 4 - MAX_DF: 0.8 - MAX_FT: 8832 - N_TOPICS: 35
# Iteration: 132 / 192 - MIN_DF: 4 - MAX_DF: 0.8 - MAX_FT: 8832 - N_TOPICS: 100
# Iteration: 133 / 192 - MIN_DF: 4 - MAX_DF: 0.9 - MAX_FT: 100 - N_TOPICS: 4
# Iteration: 134 / 192 - MIN_DF: 4 - MAX_DF: 0.9 - MAX_FT: 100 - N_TOPICS: 10
# Iteration: 135 / 192 - MIN_DF: 4 - MAX_DF: 0.9 - MAX_FT: 100 - N_TOPICS: 35
# Iteration: 136 / 192 - MIN_DF: 4 - MAX_DF: 0.9 - MAX_FT: 100 - N_TOPICS: 100
# Iteration: 137 / 192 - MIN_DF: 4 - MAX_DF: 0.9 - MAX_FT: 1000 - N_TOPICS: 4
# Iteration: 138 / 192 - MIN_DF: 4 - MAX_DF: 0.9 - MAX_FT: 1000 - N_TOPICS: 10
# Iteration: 139 / 192 - MIN_DF: 4 - MAX_DF: 0.9 - MAX_FT: 1000 - N_TOPICS: 35
# Iteration: 140 / 192 - MIN_DF: 4 - MAX_DF: 0.9 - MAX_FT: 1000 - N_TOPICS: 100
# Iteration: 141 / 192 - MIN_DF: 4 - MAX_DF: 0.9 - MAX_FT: 8832 - N_TOPICS: 4
# Iteration: 142 / 192 - MIN_DF: 4 - MAX_DF: 0.9 - MAX_FT: 8832 - N_TOPICS: 10
# Iteration: 143 / 192 - MIN_DF: 4 - MAX_DF: 0.9 - MAX_FT: 8832 - N_TOPICS: 35
# Iteration: 144 / 192 - MIN_DF: 4 - MAX_DF: 0.9 - MAX_FT: 8832 - N_TOPICS: 100
# Iteration: 145 / 192 - MIN_DF: 7 - MAX_DF: 0.6 - MAX_FT: 100 - N_TOPICS: 4
# Iteration: 146 / 192 - MIN_DF: 7 - MAX_DF: 0.6 - MAX_FT: 100 - N_TOPICS: 10
# Iteration: 147 / 192 - MIN_DF: 7 - MAX_DF: 0.6 - MAX_FT: 100 - N_TOPICS: 35
# Iteration: 148 / 192 - MIN_DF: 7 - MAX_DF: 0.6 - MAX_FT: 100 - N_TOPICS: 100
# Iteration: 149 / 192 - MIN_DF: 7 - MAX_DF: 0.6 - MAX_FT: 1000 - N_TOPICS: 4
# Iteration: 150 / 192 - MIN_DF: 7 - MAX_DF: 0.6 - MAX_FT: 1000 - N_TOPICS: 10
# Iteration: 151 / 192 - MIN_DF: 7 - MAX_DF: 0.6 - MAX_FT: 1000 - N_TOPICS: 35
# Iteration: 152 / 192 - MIN_DF: 7 - MAX_DF: 0.6 - MAX_FT: 1000 - N_TOPICS: 100
# Iteration: 153 / 192 - MIN_DF: 7 - MAX_DF: 0.6 - MAX_FT: 8832 - N_TOPICS: 4
# Iteration: 154 / 192 - MIN_DF: 7 - MAX_DF: 0.6 - MAX_FT: 8832 - N_TOPICS: 10
# Iteration: 155 / 192 - MIN_DF: 7 - MAX_DF: 0.6 - MAX_FT: 8832 - N_TOPICS: 35
# Iteration: 156 / 192 - MIN_DF: 7 - MAX_DF: 0.6 - MAX_FT: 8832 - N_TOPICS: 100
# Iteration: 157 / 192 - MIN_DF: 7 - MAX_DF: 0.7 - MAX_FT: 100 - N_TOPICS: 4
# Iteration: 158 / 192 - MIN_DF: 7 - MAX_DF: 0.7 - MAX_FT: 100 - N_TOPICS: 10
# Iteration: 159 / 192 - MIN_DF: 7 - MAX_DF: 0.7 - MAX_FT: 100 - N_TOPICS: 35
# Iteration: 160 / 192 - MIN_DF: 7 - MAX_DF: 0.7 - MAX_FT: 100 - N_TOPICS: 100
# Iteration: 161 / 192 - MIN_DF: 7 - MAX_DF: 0.7 - MAX_FT: 1000 - N_TOPICS: 4
# Iteration: 162 / 192 - MIN_DF: 7 - MAX_DF: 0.7 - MAX_FT: 1000 - N_TOPICS: 10
# Iteration: 163 / 192 - MIN_DF: 7 - MAX_DF: 0.7 - MAX_FT: 1000 - N_TOPICS: 35
# Iteration: 164 / 192 - MIN_DF: 7 - MAX_DF: 0.7 - MAX_FT: 1000 - N_TOPICS: 100
# Iteration: 165 / 192 - MIN_DF: 7 - MAX_DF: 0.7 - MAX_FT: 8832 - N_TOPICS: 4
# Iteration: 166 / 192 - MIN_DF: 7 - MAX_DF: 0.7 - MAX_FT: 8832 - N_TOPICS: 10
# Iteration: 167 / 192 - MIN_DF: 7 - MAX_DF: 0.7 - MAX_FT: 8832 - N_TOPICS: 35
# Iteration: 168 / 192 - MIN_DF: 7 - MAX_DF: 0.7 - MAX_FT: 8832 - N_TOPICS: 100
# Iteration: 169 / 192 - MIN_DF: 7 - MAX_DF: 0.8 - MAX_FT: 100 - N_TOPICS: 4
# Iteration: 170 / 192 - MIN_DF: 7 - MAX_DF: 0.8 - MAX_FT: 100 - N_TOPICS: 10
# Iteration: 171 / 192 - MIN_DF: 7 - MAX_DF: 0.8 - MAX_FT: 100 - N_TOPICS: 35
# Iteration: 172 / 192 - MIN_DF: 7 - MAX_DF: 0.8 - MAX_FT: 100 - N_TOPICS: 100
# Iteration: 173 / 192 - MIN_DF: 7 - MAX_DF: 0.8 - MAX_FT: 1000 - N_TOPICS: 4
# Iteration: 174 / 192 - MIN_DF: 7 - MAX_DF: 0.8 - MAX_FT: 1000 - N_TOPICS: 10
# Iteration: 175 / 192 - MIN_DF: 7 - MAX_DF: 0.8 - MAX_FT: 1000 - N_TOPICS: 35
# Iteration: 176 / 192 - MIN_DF: 7 - MAX_DF: 0.8 - MAX_FT: 1000 - N_TOPICS: 100
# Iteration: 177 / 192 - MIN_DF: 7 - MAX_DF: 0.8 - MAX_FT: 8832 - N_TOPICS: 4
# Iteration: 178 / 192 - MIN_DF: 7 - MAX_DF: 0.8 - MAX_FT: 8832 - N_TOPICS: 10
# Iteration: 179 / 192 - MIN_DF: 7 - MAX_DF: 0.8 - MAX_FT: 8832 - N_TOPICS: 35
# Iteration: 180 / 192 - MIN_DF: 7 - MAX_DF: 0.8 - MAX_FT: 8832 - N_TOPICS: 100
# Iteration: 181 / 192 - MIN_DF: 7 - MAX_DF: 0.9 - MAX_FT: 100 - N_TOPICS: 4
# Iteration: 182 / 192 - MIN_DF: 7 - MAX_DF: 0.9 - MAX_FT: 100 - N_TOPICS: 10
# Iteration: 183 / 192 - MIN_DF: 7 - MAX_DF: 0.9 - MAX_FT: 100 - N_TOPICS: 35
# Iteration: 184 / 192 - MIN_DF: 7 - MAX_DF: 0.9 - MAX_FT: 100 - N_TOPICS: 100
# Iteration: 185 / 192 - MIN_DF: 7 - MAX_DF: 0.9 - MAX_FT: 1000 - N_TOPICS: 4
# Iteration: 186 / 192 - MIN_DF: 7 - MAX_DF: 0.9 - MAX_FT: 1000 - N_TOPICS: 10
# Iteration: 187 / 192 - MIN_DF: 7 - MAX_DF: 0.9 - MAX_FT: 1000 - N_TOPICS: 35
# Iteration: 188 / 192 - MIN_DF: 7 - MAX_DF: 0.9 - MAX_FT: 1000 - N_TOPICS: 100
# Iteration: 189 / 192 - MIN_DF: 7 - MAX_DF: 0.9 - MAX_FT: 8832 - N_TOPICS: 4
# Iteration: 190 / 192 - MIN_DF: 7 - MAX_DF: 0.9 - MAX_FT: 8832 - N_TOPICS: 10
# Iteration: 191 / 192 - MIN_DF: 7 - MAX_DF: 0.9 - MAX_FT: 8832 - N_TOPICS: 35
# Iteration: 192 / 192 - MIN_DF: 7 - MAX_DF: 0.9 - MAX_FT: 8832 - N_TOPICS: 100
# CPU times: user 2min 4s, sys: 1min 49s, total: 3min 54s
# Wall time: 1min 25s

# %%
def extract_vocabulary(ts):
    vocab = set()
    for t in ts:
        words = [word for word, weight in t]
        vocab = vocab.union(words)
    vocab = sorted(vocab)
    r = {w: i for i, w in enumerate(vocab)}
    return r

def get_weights(t):
    return dict(t)

def create_vector(vocab, weights):
    r = [0] * len(vocab)
    for wo in weights:
        r[vocab[wo]] = weights[wo]
    return r

def vectorize(ts):
    r = []
    ts = [t for i, t in ts]
    vocab = extract_vocabulary(ts)
    for t in ts:
        weights = get_weights(t)
        vector = create_vector(vocab, weights)
        r.append(vector)
    return r

# %%
def two_topics_distance(t1, t2):
    r = spatial.distance.cosine(t1, t2)
    return r

def multiple_topics_distance(ts):
    ds = []
    for i, t1 in enumerate(ts[:-1]):
        for j in range(i + 1, len(ts)):
            t2 = ts[j]
            d = two_topics_distance(t1, t2)
            ds.append(d)
    return np.mean(ds)

def best_topics(ts_lst):
    r = []
    for ts in ts_lst:
        ts_vector = vectorize(ts[0])
        d = multiple_topics_distance(ts_vector)
        r.append((d, ts))
    r = sorted(r, reverse=True)
    return r[0]

# %%
# %%time

# print('LSI')
# lsi_best_topics = best_topics(lsi_topics_lst)
print('LDA')
lda_best_topics = best_topics(lda_topics_lst)
print('HDP')
hdp_best_topics = best_topics(hdp_topics_lst)
# Out:
# LDA
# HDP
# CPU times: user 32.8 s, sys: 292 ms, total: 33.1 s
# Wall time: 32.8 s

# %% [markdown]
# ## Results

# %% [markdown]
# ### LSI

# %% [markdown]
# #### Topics

# %%
# lsi_best_topics[1][0]

# %% [markdown]
# #### Association document-topics

# %%
# corpus = lsi_best_topics[1][2]
# for doc in corpus:
#     print(doc)

# %% [markdown]
# #### Topics sorted by recurrence

# %%
# total_weights = defaultdict(float)
# for doc in corpus:
#     for topic, weight in doc:
#         total_weights[topic] += abs(weight)
# total_weights = dict(total_weights)

# %%
# Counter(total_weights).most_common()

# %% [markdown]
# ### LDA

# %% [markdown]
# #### Topics

# %%
lda_best_topics[1][0]
# Out:
# [(0,
#   [('general', 0.015070368),
#    ('mesa', 0.011503357),
#    ('marco', 0.00990339),
#    ('internacional', 0.0096022291),
#    ('ver', 0.0095808012),
#    ('lucha', 0.008745254),
#    ('años', 0.0082478374),
#    ('colombiano', 0.0077144005),
#    ('ejemplo', 0.0072955685),
#    ('temas', 0.0070030349)]),
#  (1,
#   [('víctimas', 0.044044901),
#    ('ley', 0.028937127),
#    ('reparación', 0.022934349),
#    ('farc', 0.016626451),
#    ('hoy', 0.01286369),
#    ('carlos', 0.012476814),
#    ('sociedad', 0.011274189),
#    ('atención', 0.010892768),
#    ('zona', 0.010325162),
#    ('justicia', 0.01002058)]),
#  (2,
#   [('agenda', 0.014964212),
#    ('participación', 0.013239958),
#    ('fase', 0.012774641),
#    ('mesa', 0.010934199),
#    ('conversaciones', 0.010594905),
#    ('desarrollo', 0.0090510938),
#    ('puntos', 0.0086087752),
#    ('acordado', 0.0086054588),
#    ('terminación', 0.0081842206),
#    ('farc', 0.008114134)]),
#  (3,
#   [('equipo', 0.015996316),
#    ('farc', 0.0098988106),
#    ('importante', 0.0095360698),
#    ('forma', 0.0094257323),
#    ('reconciliación', 0.0088087209),
#    ('agenda', 0.0086260457),
#    ('justicia', 0.0084327105),
#    ('víctimas', 0.0082965577),
#    ('general', 0.0078175562),
#    ('años', 0.0075341435)]),
#  (4,
#   [('negociación', 0.033067405),
#    ('farc', 0.021329248),
#    ('víctimas', 0.012842311),
#    ('paso', 0.0098728612),
#    ('sistema', 0.0096422117),
#    ('justicia', 0.0092356801),
#    ('propuestas', 0.0084062461),
#    ('general', 0.0070834621),
#    ('participación', 0.0068549002),
#    ('posible', 0.0065028733)]),
#  (5,
#   [('víctimas', 0.016940398),
#    ('farc', 0.015216202),
#    ('agenda', 0.013880258),
#    ('negociación', 0.013423793),
#    ('general', 0.0091502061),
#    ('final', 0.0085210856),
#    ('hoy', 0.0082613677),
#    ('fase', 0.0078724828),
#    ('colombianos', 0.00785142),
#    ('conversaciones', 0.0069047227)]),
#  (6,
#   [('mesa', 0.010569379),
#    ('delegados', 0.010136796),
#    ('paso', 0.0090550035),
#    ('negociación', 0.0089832321),
#    ('primer', 0.0085476069),
#    ('acosta', 0.0079508731),
#    ('armado', 0.0071228896),
#    ('agenda', 0.0070737782),
#    ('importante', 0.0069558462),
#    ('marco', 0.0068010804)]),
#  (7,
#   [('farc', 0.019978683),
#    ('zona', 0.014114312),
#    ('actores', 0.01225296),
#    ('negociación', 0.012018667),
#    ('través', 0.011215768),
#    ('señor', 0.010222365),
#    ('carlos', 0.010026706),
#    ('alto', 0.0097613446),
#    ('comisionado', 0.0087411795),
#    ('víctimas', 0.0079524415)]),
#  (8,
#   [('desarrollo', 0.014749495),
#    ('hoy', 0.012224397),
#    ('gran', 0.011345424),
#    ('colombianos', 0.0081772134),
#    ('fuerzas', 0.0073461449),
#    ('trabajo', 0.0073319916),
#    ('social', 0.0072368681),
#    ('participación', 0.0067641241),
#    ('justicia', 0.0066513922),
#    ('mesa', 0.0066099903)]),
#  (9,
#   [('víctimas', 0.01414083),
#    ('hoy', 0.013111841),
#    ('colombianos', 0.01086097),
#    ('violencia', 0.010645367),
#    ('conversaciones', 0.009976685),
#    ('ley', 0.0097147161),
#    ('fase', 0.0093820849),
#    ('internacional', 0.0087939007),
#    ('garantías', 0.0081470478),
#    ('historia', 0.0074376273)]),
#  (10,
#   [('desarrollo', 0.017185489),
#    ('colombianos', 0.012199215),
#    ('gran', 0.011605568),
#    ('hoy', 0.01133021),
#    ('social', 0.010723963),
#    ('programas', 0.010518911),
#    ('marco', 0.0099051036),
#    ('justicia', 0.0090469867),
#    ('nuevo', 0.0085466998),
#    ('fuerzas', 0.0085008889)]),
#  (11,
#   [('víctimas', 0.018864211),
#    ('ley', 0.015614458),
#    ('negociación', 0.013698141),
#    ('reparación', 0.0094371876),
#    ('farc', 0.0083222445),
#    ('justicia', 0.0082566785),
#    ('colombianos', 0.0078123431),
#    ('hoy', 0.0076610125),
#    ('ahora', 0.0062738932),
#    ('día', 0.0061464547)]),
#  (12,
#   [('farc', 0.022573562),
#    ('general', 0.010315503),
#    ('octubre', 0.0093503678),
#    ('carlos', 0.0091889836),
#    ('agosto', 0.0086800875),
#    ('carta', 0.0076090391),
#    ('alto', 0.0074492339),
#    ('zona', 0.0072853905),
#    ('comandante', 0.0072306339),
#    ('pública', 0.0069934209)]),
#  (13,
#   [('agenda', 0.018375894),
#    ('temas', 0.011285757),
#    ('desarrollo', 0.010614501),
#    ('marco', 0.010030078),
#    ('seguridad', 0.0087735634),
#    ('objetivo', 0.008551063),
#    ('armado', 0.0083342716),
#    ('final', 0.0082817608),
#    ('participación', 0.0082242507),
#    ('programas', 0.0080553293)]),
#  (14,
#   [('agenda', 0.024921238),
#    ('temas', 0.018150028),
#    ('seguridad', 0.011016647),
#    ('objetivo', 0.010042502),
#    ('armado', 0.009963668),
#    ('día', 0.0098883947),
#    ('marco', 0.0092801359),
#    ('negociación', 0.0091231167),
#    ('posible', 0.0089885369),
#    ('partes', 0.0089507131)]),
#  (15,
#   [('pueblo', 0.029387634),
#    ('comandante', 0.02615374),
#    ('alfonso', 0.020610185),
#    ('hoy', 0.013697973),
#    ('cano', 0.01305699),
#    ('militar', 0.012212138),
#    ('militares', 0.01112028),
#    ('guerra', 0.010426409),
#    ('nuevo', 0.010258091),
#    ('nueva', 0.009611615)]),
#  (16,
#   [('febrero', 0.019830355),
#    ('henry', 0.010633967),
#    ('agosto', 0.010184167),
#    ('fecha', 0.010096955),
#    ('farc', 0.0098612225),
#    ('negociación', 0.0093523879),
#    ('jaramillo', 0.0092309928),
#    ('primer', 0.009171431),
#    ('noruega', 0.0090688411),
#    ('armado', 0.0089035351)]),
#  (17,
#   [('delegados', 0.069710098),
#    ('venezuela', 0.039846238),
#    ('partes', 0.03356193),
#    ('noruega', 0.023897896),
#    ('traslado', 0.023811914),
#    ('gobiernos', 0.023663143),
#    ('equipo', 0.017857824),
#    ('técnico', 0.017418426),
#    ('acta', 0.016294699),
#    ('miembro', 0.014977258)]),
#  (18,
#   [('farc', 0.024359655),
#    ('carta', 0.011785449),
#    ('delegados', 0.010102555),
#    ('lucha', 0.0093715973),
#    ('negociación', 0.0087369559),
#    ('octubre', 0.0083696963),
#    ('colombiano', 0.008076149),
#    ('seguridad', 0.0074704061),
#    ('enero', 0.0074464679),
#    ('central', 0.0074390937)]),
#  (19,
#   [('hoy', 0.018066408),
#    ('diferente', 0.013408412),
#    ('colombianos', 0.013150218),
#    ('conversaciones', 0.012785974),
#    ('farc', 0.011671458),
#    ('hablar', 0.011250732),
#    ('víctimas', 0.010788945),
#    ('fase', 0.010702872),
#    ('violencia', 0.010403169),
#    ('quiero', 0.01010924)]),
#  (20,
#   [('farc', 0.046970181),
#    ('zona', 0.028964702),
#    ('señor', 0.017035702),
#    ('comisionado', 0.015928505),
#    ('importantes', 0.015356628),
#    ('carlos', 0.015142813),
#    ('uribe', 0.014791782),
#    ('seguridad', 0.013616425),
#    ('humanitario', 0.013408624),
#    ('alto', 0.013027097)]),
#  (21,
#   [('años', 0.016445108),
#    ('paso', 0.01231674),
#    ('sergio', 0.011659916),
#    ('mesa', 0.010815249),
#    ('equipo', 0.010606594),
#    ('comisionado', 0.010106921),
#    ('importante', 0.0099648964),
#    ('buena', 0.0090372888),
#    ('jaramillo', 0.0088928165),
#    ('agenda', 0.0079935044)]),
#  (22,
#   [('hoy', 0.013346481),
#    ('colombianos', 0.01027995),
#    ('farc', 0.0096052568),
#    ('terminar', 0.0090634311),
#    ('hablar', 0.0087021971),
#    ('fase', 0.0085855657),
#    ('violencia', 0.007985618),
#    ('diferente', 0.0075754551),
#    ('quiero', 0.0073977252),
#    ('víctimas', 0.0067335842)]),
#  (23,
#   [('paso', 0.036157995),
#    ('equipo', 0.016978271),
#    ('importante', 0.016487001),
#    ('años', 0.01573343),
#    ('sergio', 0.015212502),
#    ('buena', 0.013804911),
#    ('congreso', 0.01259851),
#    ('comisionado', 0.012213743),
#    ('trabajo', 0.011361218),
#    ('justicia', 0.010458179)]),
#  (24,
#   [('fase', 0.019548429),
#    ('mesa', 0.014239162),
#    ('equipo', 0.012814634),
#    ('trabajo', 0.012150396),
#    ('noruega', 0.011302411),
#    ('general', 0.011171269),
#    ('conversaciones', 0.010019084),
#    ('jaramillo', 0.0096649816),
#    ('negociadores', 0.0082492698),
#    ('agenda', 0.0073830206)]),
#  (25,
#   [('víctimas', 0.018697925),
#    ('armado', 0.017329838),
#    ('lograr', 0.015848279),
#    ('negociación', 0.011014821),
#    ('interno', 0.010179137),
#    ('ley', 0.0099796597),
#    ('hoja', 0.0094851926),
#    ('nación', 0.0091627622),
#    ('ruta', 0.0082022725),
#    ('político', 0.0081678657)]),
#  (26,
#   [('farc', 0.015008219),
#    ('agenda', 0.013850969),
#    ('partes', 0.013551751),
#    ('venezuela', 0.013402674),
#    ('garantes', 0.011432901),
#    ('fase', 0.009948316),
#    ('conversaciones', 0.0097801927),
#    ('hoy', 0.0092167333),
#    ('delegados', 0.0084822699),
#    ('internacionales', 0.0082102474)]),
#  (27,
#   [('construcción', 0.020984696),
#    ('acuerdos', 0.016708914),
#    ('mesa', 0.016690655),
#    ('final', 0.015615307),
#    ('estable', 0.015335728),
#    ('delegaciones', 0.014437666),
#    ('duradera', 0.01435945),
#    ('terminación', 0.013430923),
#    ('general', 0.012876864),
#    ('participación', 0.012620484)]),
#  (28,
#   [('pueblo', 0.032270048),
#    ('alfonso', 0.027875802),
#    ('comandante', 0.020900352),
#    ('militar', 0.017302977),
#    ('hoy', 0.017068364),
#    ('cano', 0.014668287),
#    ('nuevo', 0.01340434),
#    ('dignidad', 0.011973677),
#    ('muerte', 0.011338003),
#    ('guerrilla', 0.01101925)]),
#  (29,
#   [('fase', 0.025041604),
#    ('mesa', 0.01919248),
#    ('agenda', 0.013650725),
#    ('noruega', 0.011398276),
#    ('general', 0.010380383),
#    ('conversaciones', 0.010169894),
#    ('puntos', 0.0090070441),
#    ('jaramillo', 0.0087070391),
#    ('delegación', 0.0086202556),
#    ('negociación', 0.0085992534)]),
#  (30,
#   [('mesa', 0.011266928),
#    ('farc', 0.011090145),
#    ('participación', 0.0099155027),
#    ('marco', 0.0099094454),
#    ('negociación', 0.0090335561),
#    ('general', 0.0085234223),
#    ('desarrollo', 0.0078102564),
#    ('momento', 0.0071085589),
#    ('víctimas', 0.006879793),
#    ('colombianos', 0.0068381503)]),
#  (31,
#   [('comandante', 0.023635279),
#    ('pueblo', 0.021323813),
#    ('alfonso', 0.018478241),
#    ('cano', 0.013080859),
#    ('militar', 0.013052691),
#    ('muerte', 0.010468055),
#    ('dignidad', 0.0097628729),
#    ('noviembre', 0.0084134825),
#    ('secretariado', 0.0082338648),
#    ('montañas', 0.0081203263)]),
#  (32,
#   [('mesa', 0.019073239),
#    ('general', 0.013292829),
#    ('fase', 0.010566393),
#    ('conversaciones', 0.010262714),
#    ('equipo', 0.0098049659),
#    ('negociación', 0.00841361),
#    ('jaramillo', 0.0083397049),
#    ('agenda', 0.0079803001),
#    ('agosto', 0.0079211658),
#    ('pública', 0.0074754399)]),
#  (33,
#   [('agenda', 0.018618328),
#    ('equipo', 0.010075002),
#    ('participación', 0.010037177),
#    ('marco', 0.0086948955),
#    ('final', 0.0083422419),
#    ('mesa', 0.0080762748),
#    ('fase', 0.0080167744),
#    ('temas', 0.0079752058),
#    ('general', 0.0078544598),
#    ('seguridad', 0.0066836732)]),
#  (34,
#   [('exploratorio', 0.078594662),
#    ('delegados', 0.032538347),
#    ('farc', 0.030759798),
#    ('venezuela', 0.028618112),
#    ('general', 0.019478329),
#    ('inicio', 0.017409438),
#    ('preparatoria', 0.017199533),
#    ('primera', 0.016976001),
#    ('partes', 0.015537495),
#    ('noruega', 0.014450186)]),
#  (35,
#   [('mesa', 0.012331982),
#    ('colombianos', 0.011898637),
#    ('conversaciones', 0.011754288),
#    ('agenda', 0.010659969),
#    ('diálogo', 0.0098229842),
#    ('hoy', 0.0087814806),
#    ('guerra', 0.008364452),
#    ('general', 0.0082574496),
#    ('fase', 0.0078256987),
#    ('llegar', 0.0075639011)]),
#  (36,
#   [('exploratorio', 0.037031002),
#    ('delegados', 0.028685099),
#    ('noruega', 0.023960207),
#    ('venezuela', 0.018529553),
#    ('partes', 0.015015307),
#    ('traslado', 0.014678026),
#    ('equipo', 0.011780371),
#    ('febrero', 0.011529655),
#    ('delegación', 0.011261202),
#    ('gobiernos', 0.010182768)]),
#  (37,
#   [('mesa', 0.012796236),
#    ('desarrollo', 0.0095162429),
#    ('hoy', 0.0092318449),
#    ('diálogo', 0.0083588352),
#    ('colombianos', 0.0082879337),
#    ('general', 0.0079383561),
#    ('jaramillo', 0.0079326425),
#    ('momento', 0.0077035865),
#    ('conversaciones', 0.0073187719),
#    ('gran', 0.0065946649)]),
#  (38,
#   [('mesa', 0.005764782),
#    ('diálogo', 0.0053009903),
#    ('desarrollo', 0.0046163378),
#    ('presidencia', 0.0045404844),
#    ('miembros', 0.0038667195),
#    ('representantes', 0.0038529923),
#    ('solución', 0.0038353191),
#    ('años', 0.0038028557),
#    ('medios', 0.0037779124),
#    ('ley', 0.0035974842)]),
#  (39,
#   [('general', 0.051401228),
#    ('estable', 0.029729495),
#    ('duradera', 0.02699689),
#    ('terminación', 0.026083415),
#    ('construcción', 0.023577239),
#    ('delegaciones', 0.02204771),
#    ('noruega', 0.021192145),
#    ('firma', 0.019420631),
#    ('mesa', 0.017751655),
#    ('exploratorio', 0.01716874)]),
#  (40,
#   [('mesa', 0.015006981),
#    ('desarrollo', 0.010060776),
#    ('marco', 0.0092353262),
#    ('diálogo', 0.009018735),
#    ('jaramillo', 0.0084760934),
#    ('participación', 0.0079132253),
#    ('exploratorio', 0.0071291742),
#    ('puntos', 0.0069329375),
#    ('seguridad', 0.0068918536),
#    ('internacional', 0.0068582487)]),
#  (41,
#   [('social', 0.01711051),
#    ('farc', 0.016696179),
#    ('central', 0.013688142),
#    ('carta', 0.013290623),
#    ('lucha', 0.012928805),
#    ('reconciliación', 0.011117345),
#    ('colombiano', 0.010194087),
#    ('pueblo', 0.010084),
#    ('agenda', 0.0092637688),
#    ('acuerdos', 0.0091683986)]),
#  (42,
#   [('agenda', 0.011924565),
#    ('desarrollo', 0.011480447),
#    ('participación', 0.0097595407),
#    ('social', 0.0088686049),
#    ('marco', 0.0080698896),
#    ('seguridad', 0.0075362632),
#    ('programas', 0.0073218825),
#    ('temas', 0.0072467593),
#    ('armado', 0.0072128219),
#    ('objetivo', 0.0069294455)]),
#  (43,
#   [('desarrollo', 0.019434961),
#    ('participación', 0.014782319),
#    ('presidencia', 0.014113164),
#    ('marco', 0.013836639),
#    ('programas', 0.013431392),
#    ('mesa', 0.013335954),
#    ('seguridad', 0.0091357594),
#    ('general', 0.0086367056),
#    ('alto', 0.0084056649),
#    ('sergio', 0.0077125491)]),
#  (44,
#   [('agenda', 0.014083712),
#    ('conversaciones', 0.011916371),
#    ('fase', 0.010187481),
#    ('víctimas', 0.0096381223),
#    ('general', 0.0089357952),
#    ('marco', 0.0084482338),
#    ('seguridad', 0.008043319),
#    ('armado', 0.0076547661),
#    ('negociación', 0.0074781668),
#    ('final', 0.0072035659)]),
#  (45,
#   [('víctimas', 0.024779443),
#    ('general', 0.017724315),
#    ('ley', 0.011843744),
#    ('sociedad', 0.0091393739),
#    ('programas', 0.0089678708),
#    ('desarrollo', 0.0089054871),
#    ('reparación', 0.0087897331),
#    ('participación', 0.0084814904),
#    ('negociación', 0.0082809394),
#    ('justicia', 0.0079572825)]),
#  (46,
#   [('programas', 0.014475025),
#    ('desarrollo', 0.014254095),
#    ('participación', 0.014089886),
#    ('marco', 0.012127611),
#    ('pablo', 0.011747885),
#    ('catatumbo', 0.011558263),
#    ('alfonso', 0.010016717),
#    ('mecanismos', 0.009789723),
#    ('social', 0.009597416),
#    ('guerra', 0.0086707054)]),
#  (47,
#   [('farc', 0.017802101),
#    ('carta', 0.014135834),
#    ('mesa', 0.013762992),
#    ('central', 0.013064891),
#    ('lucha', 0.013029441),
#    ('social', 0.012119628),
#    ('diálogo', 0.011929242),
#    ('reconciliación', 0.011835665),
#    ('acuerdos', 0.011221939),
#    ('desarrollo', 0.011151137)]),
#  (48,
#   [('gran', 0.013529833),
#    ('colombianos', 0.012969517),
#    ('hoy', 0.012714882),
#    ('trabajo', 0.011000078),
#    ('nuevo', 0.010421974),
#    ('equipo', 0.010116611),
#    ('día', 0.00863929),
#    ('patria', 0.0084963478),
#    ('fuerzas', 0.0084879249),
#    ('guerra', 0.0072856406)]),
#  (49,
#   [('víctimas', 0.040366653),
#    ('ley', 0.019572742),
#    ('reparación', 0.016648231),
#    ('hoy', 0.015060263),
#    ('colombianos', 0.011597509),
#    ('violencia', 0.010957121),
#    ('años', 0.010345694),
#    ('sociedad', 0.0096915988),
#    ('día', 0.0087271817),
#    ('mundo', 0.008470376)]),
#  (50,
#   [('desarrollo', 0.026850168),
#    ('mesa', 0.021478863),
#    ('participación', 0.016198294),
#    ('agenda', 0.014448549),
#    ('programas', 0.014383308),
#    ('actas', 0.013701652),
#    ('integral', 0.0117366),
#    ('mecanismos', 0.011138285),
#    ('puntos', 0.010479744),
#    ('plenipotenciario', 0.010302782)]),
#  (51,
#   [('víctimas', 0.01625674),
#    ('programas', 0.015263311),
#    ('general', 0.013088141),
#    ('desarrollo', 0.01300842),
#    ('negociación', 0.012298301),
#    ('participación', 0.011786821),
#    ('marco', 0.010062088),
#    ('construcción', 0.0082787247),
#    ('medidas', 0.0080841416),
#    ('mesa', 0.0080705769)]),
#  (52,
#   [('sergio', 0.014888301),
#    ('paso', 0.014213332),
#    ('equipo', 0.013712403),
#    ('años', 0.011845295),
#    ('trabajo', 0.01019375),
#    ('momento', 0.0099302018),
#    ('desarrollo', 0.0092330789),
#    ('importante', 0.0091218241),
#    ('hoy', 0.0088589406),
#    ('jaramillo', 0.0088009909)]),
#  (53,
#   [('farc', 0.014136463),
#    ('pueblo', 0.010141333),
#    ('comandante', 0.010034665),
#    ('negociación', 0.010008927),
#    ('hoy', 0.0099857384),
#    ('justicia', 0.0092143007),
#    ('alfonso', 0.0083310781),
#    ('delegados', 0.0082250293),
#    ('cano', 0.0076655014),
#    ('colombianos', 0.007627978)]),
#  (54,
#   [('víctimas', 0.035962559),
#    ('años', 0.016644811),
#    ('hoy', 0.01615808),
#    ('ley', 0.014923817),
#    ('reparación', 0.011227245),
#    ('mundo', 0.010389883),
#    ('farc', 0.0097102923),
#    ('justicia', 0.0094068535),
#    ('colombianos', 0.0089588938),
#    ('carlos', 0.0081502749)]),
#  (55,
#   [('víctimas', 0.011823216),
#    ('desarrollo', 0.010819845),
#    ('seguridad', 0.0089391954),
#    ('ley', 0.0084240651),
#    ('agenda', 0.0079883896),
#    ('programas', 0.0076914094),
#    ('delegados', 0.0070533971),
#    ('social', 0.0069656512),
#    ('mesa', 0.0068408251),
#    ('marco', 0.0068220771)]),
#  (56,
#   [('hoy', 0.01149076),
#    ('trabajo', 0.0090838186),
#    ('fuerzas', 0.0086992737),
#    ('mesa', 0.0084283585),
#    ('general', 0.0083882557),
#    ('gran', 0.0081751347),
#    ('víctimas', 0.0081588589),
#    ('colombianos', 0.0076404498),
#    ('social', 0.0075948061),
#    ('equipo', 0.0075117159)]),
#  (57,
#   [('negociación', 0.016913509),
#    ('conversaciones', 0.014227114),
#    ('agenda', 0.011707269),
#    ('armado', 0.011440236),
#    ('objetivo', 0.011114869),
#    ('construcción', 0.011008123),
#    ('general', 0.0087757902),
#    ('farc', 0.0084549878),
#    ('años', 0.0084122615),
#    ('delegación', 0.0083326166)]),
#  (58,
#   [('exploratorio', 0.033205099),
#    ('primera', 0.015637426),
#    ('general', 0.013875072),
#    ('construcción', 0.013820918),
#    ('fase', 0.013494291),
#    ('terminación', 0.012393817),
#    ('duradera', 0.011859185),
#    ('preparatoria', 0.011577185),
#    ('marco', 0.011247898),
#    ('inicio', 0.011224804)]),
#  (59,
#   [('delegación', 0.045325022),
#    ('delegados', 0.02339028),
#    ('posible', 0.023085872),
#    ('noruega', 0.022973053),
#    ('secretariado', 0.022913575),
#    ('nombre', 0.022533387),
#    ('segundo', 0.022427579),
#    ('nota', 0.022405785),
#    ('pablo', 0.022380492),
#    ('guerra', 0.012783499)]),
#  (60,
#   [('farc', 0.025382476),
#    ('negociación', 0.013327412),
#    ('partes', 0.011310771),
#    ('agenda', 0.010525784),
#    ('víctimas', 0.010516339),
#    ('venezuela', 0.009668109),
#    ('justicia', 0.0086349286),
#    ('mesa', 0.0085731903),
#    ('garantes', 0.007983665),
#    ('posible', 0.0077231359)]),
#  (61,
#   [('mesa', 0.018019548),
#    ('mundo', 0.013286876),
#    ('años', 0.011586972),
#    ('guerra', 0.0088290088),
#    ('colombianos', 0.0078521799),
#    ('mauricio', 0.0074646934),
#    ('negociación', 0.0073250178),
#    ('víctimas', 0.0071879476),
#    ('negociaciones', 0.0068722595),
#    ('momento', 0.0068274708)]),
#  (62,
#   [('fase', 0.022325624),
#    ('noruega', 0.019466214),
#    ('víctimas', 0.016524402),
#    ('agenda', 0.015165571),
#    ('oslo', 0.013355268),
#    ('mesa', 0.012671941),
#    ('delegación', 0.012425295),
#    ('general', 0.011614322),
#    ('construcción', 0.010811543),
#    ('terminación', 0.010030093)]),
#  (63,
#   [('febrero', 0.021937147),
#    ('farc', 0.021151083),
#    ('negociación', 0.019748587),
#    ('fecha', 0.017266518),
#    ('cuenta', 0.015758293),
#    ('carta', 0.014705427),
#    ('pablo', 0.014297022),
#    ('guerra', 0.01328144),
#    ('años', 0.013037088),
#    ('único', 0.011687879)]),
#  (64,
#   [('agenda', 0.016145583),
#    ('desarrollo', 0.014277352),
#    ('participación', 0.013595132),
#    ('mesa', 0.012379199),
#    ('acuerdos', 0.012086117),
#    ('conversaciones', 0.010112548),
#    ('puntos', 0.0095969597),
#    ('acordado', 0.0086336061),
#    ('plenipotenciario', 0.0086284308),
#    ('construcción', 0.0082296459)]),
#  (65,
#   [('mesa', 0.017214416),
#    ('colombianos', 0.011737067),
#    ('hoy', 0.010488732),
#    ('desarrollo', 0.010117397),
#    ('gran', 0.0099584721),
#    ('trabajo', 0.0098550133),
#    ('social', 0.0093587488),
#    ('momento', 0.0086876713),
#    ('fuerzas', 0.0084038209),
#    ('justicia', 0.0074610156)]),
#  (66,
#   [('agenda', 0.027853215),
#    ('participación', 0.022489881),
#    ('puntos', 0.021032779),
#    ('fase', 0.020797471),
#    ('trata', 0.019355385),
#    ('acuerdos', 0.01484794),
#    ('final', 0.014688529),
#    ('mesa', 0.013651284),
#    ('implementación', 0.012857494),
#    ('armas', 0.012301293)]),
#  (67,
#   [('carta', 0.026547054),
#    ('alfonso', 0.026384959),
#    ('comisionado', 0.018609757),
#    ('cano', 0.018383326),
#    ('respuesta', 0.018343516),
#    ('diálogos', 0.018279063),
#    ('caso', 0.018114956),
#    ('respeto', 0.018038126),
#    ('pearl', 0.018036565),
#    ('pablo', 0.017986521)]),
#  (68,
#   [('hoy', 0.017322091),
#    ('gran', 0.016243912),
#    ('mundo', 0.011379349),
#    ('colombianos', 0.010609627),
#    ('fuerzas', 0.010006336),
#    ('nuevo', 0.0086876964),
#    ('trabajo', 0.0084438389),
#    ('social', 0.0080451984),
#    ('justicia', 0.0076068109),
#    ('desarrollo', 0.0072735534)]),
#  (69,
#   [('delegados', 0.018950386),
#    ('víctimas', 0.015289163),
#    ('venezuela', 0.012867598),
#    ('ley', 0.010707612),
#    ('traslado', 0.010142245),
#    ('farc', 0.0092408173),
#    ('noruega', 0.0091780648),
#    ('seguridad', 0.0089587457),
#    ('mesa', 0.0086100455),
#    ('fuerzas', 0.0080780108)]),
#  (70,
#   [('delegados', 0.038918521),
#    ('primer', 0.026780462),
#    ('pablo', 0.023380319),
#    ('central', 0.018710099),
#    ('propuesta', 0.018575406),
#    ('secretariado', 0.016549632),
#    ('carta', 0.015376901),
#    ('catatumbo', 0.014173453),
#    ('henry', 0.01395091),
#    ('acosta', 0.01326587)]),
#  (71,
#   [('conversaciones', 0.015214019),
#    ('víctimas', 0.011070009),
#    ('armado', 0.010981667),
#    ('agenda', 0.0098421965),
#    ('negociación', 0.0077064722),
#    ('final', 0.0075767231),
#    ('tierras', 0.007478728),
#    ('violencia', 0.0072345748),
#    ('lograr', 0.0068932134),
#    ('participación', 0.0066714622)]),
#  (72,
#   [('desarrollo', 0.020322088),
#    ('general', 0.010877784),
#    ('participación', 0.010278179),
#    ('mesa', 0.0095930044),
#    ('seguridad', 0.0088640908),
#    ('marco', 0.0084339827),
#    ('programas', 0.0079052141),
#    ('diálogo', 0.007785249),
#    ('conversaciones', 0.0076982691),
#    ('terminación', 0.0074729775)]),
#  (73,
#   [('farc', 0.020036357),
#    ('años', 0.010064739),
#    ('lucha', 0.0098573696),
#    ('armado', 0.0091928411),
#    ('diálogo', 0.0086666672),
#    ('seguridad', 0.0084701469),
#    ('colombiano', 0.007593249),
#    ('internacional', 0.0075444765),
#    ('agenda', 0.0072668907),
#    ('zona', 0.0072397408)]),
#  (74,
#   [('farc', 0.020132428),
#    ('zona', 0.015160775),
#    ('carlos', 0.011034401),
#    ('mesa', 0.010889115),
#    ('actores', 0.0076227393),
#    ('comisionado', 0.0075154691),
#    ('uribe', 0.0069617042),
#    ('importantes', 0.0065178052),
#    ('general', 0.0064387145),
#    ('conversaciones', 0.0063123354)]),
#  (75,
#   [('negociación', 0.0092148231),
#    ('fase', 0.0077932607),
#    ('general', 0.0077414247),
#    ('mesa', 0.0064251986),
#    ('farc', 0.0063898726),
#    ('agenda', 0.0063084462),
#    ('agosto', 0.0062277215),
#    ('primera', 0.0059258565),
#    ('conversaciones', 0.0057288404),
#    ('víctimas', 0.0055484883)]),
#  (76,
#   [('construcción', 0.019214202),
#    ('conversaciones', 0.012400707),
#    ('armado', 0.011734862),
#    ('delegación', 0.010322375),
#    ('marco', 0.0099863363),
#    ('exploratorio', 0.0097584501),
#    ('sociedad', 0.0095723746),
#    ('años', 0.0091737118),
#    ('día', 0.0089210244),
#    ('jaramillo', 0.0080336807)]),
#  (77,
#   [('farc', 0.017941484),
#    ('agenda', 0.01501322),
#    ('zona', 0.011790005),
#    ('fase', 0.01112073),
#    ('conversaciones', 0.0093170609),
#    ('general', 0.0091574611),
#    ('delegación', 0.008063185),
#    ('agosto', 0.0077041183),
#    ('carlos', 0.0076310197),
#    ('uribe', 0.0074365954)]),
#  (78,
#   [('agenda', 0.017692553),
#    ('mesa', 0.016049694),
#    ('acordado', 0.011851563),
#    ('participación', 0.01184561),
#    ('final', 0.010721629),
#    ('trata', 0.010591445),
#    ('acuerdos', 0.010194018),
#    ('terminación', 0.009726746),
#    ('puntos', 0.0096618682),
#    ('desarrollo', 0.0095747756)]),
#  (79,
#   [('mesa', 0.02992806),
#    ('diálogo', 0.012971604),
#    ('desarrollo', 0.011046982),
#    ('años', 0.010550346),
#    ('colombianos', 0.0092685772),
#    ('diálogos', 0.0088883769),
#    ('presidencia', 0.0079489239),
#    ('mundo', 0.0076450603),
#    ('delegación', 0.007237379),
#    ('participación', 0.0070943814)]),
#  (80,
#   [('farc', 0.060297057),
#    ('zona', 0.026930541),
#    ('carlos', 0.019184135),
#    ('señor', 0.015819753),
#    ('actores', 0.015377493),
#    ('luis', 0.014773381),
#    ('importantes', 0.014287504),
#    ('octubre', 0.014064872),
#    ('uribe', 0.013767207),
#    ('humanitario', 0.01314768)]),
#  (81,
#   [('ley', 0.044749685),
#    ('víctimas', 0.044108883),
#    ('hoy', 0.023817521),
#    ('sociedad', 0.019557754),
#    ('reparación', 0.019316792),
#    ('tierras', 0.014240123),
#    ('colombianos', 0.013848349),
#    ('violencia', 0.012925275),
#    ('social', 0.012110876),
#    ('atención', 0.012088371)]),
#  (82,
#   [('víctimas', 0.016379386),
#    ('fase', 0.01160933),
#    ('agenda', 0.010666084),
#    ('participación', 0.0099797416),
#    ('nuevo', 0.0085579241),
#    ('negociación', 0.0085125985),
#    ('desarrollo', 0.0084717637),
#    ('justicia', 0.0083120102),
#    ('ley', 0.0072061401),
#    ('marco', 0.0071020536)]),
#  (83,
#   [('participación', 0.017976994),
#    ('desarrollo', 0.017274773),
#    ('fase', 0.015783407),
#    ('programas', 0.014957046),
#    ('marco', 0.012448271),
#    ('social', 0.011953937),
#    ('pública', 0.010240342),
#    ('información', 0.010237085),
#    ('agenda', 0.010203566),
#    ('general', 0.0093324324)]),
#  (84,
#   [('agenda', 0.017841524),
#    ('seguridad', 0.010713739),
#    ('temas', 0.0090060541),
#    ('marco', 0.0077763563),
#    ('desarrollo', 0.0077149598),
#    ('internacionales', 0.0072076158),
#    ('fuerzas', 0.0070029283),
#    ('posible', 0.0068773958),
#    ('día', 0.0068117562),
#    ('exploratorio', 0.0066388007)]),
#  (85,
#   [('alto', 0.028915387),
#    ('fase', 0.023977326),
#    ('sergio', 0.02313921),
#    ('presidencia', 0.021449074),
#    ('comisionado', 0.020591738),
#    ('jaramillo', 0.016986113),
#    ('agenda', 0.016747596),
#    ('oslo', 0.014014747),
#    ('delegación', 0.013291072),
#    ('mesa', 0.012874725)]),
#  (86,
#   [('desarrollo', 0.016929386),
#    ('social', 0.010181573),
#    ('mesa', 0.010082057),
#    ('programas', 0.0099086249),
#    ('marco', 0.0087854872),
#    ('diálogo', 0.0087045981),
#    ('seguridad', 0.0084066261),
#    ('agenda', 0.0082998136),
#    ('participación', 0.0081813382),
#    ('negociación', 0.0075785904)]),
#  (87,
#   [('paso', 0.022986406),
#    ('sergio', 0.015826385),
#    ('mesa', 0.01434),
#    ('años', 0.013609603),
#    ('equipo', 0.013265643),
#    ('buena', 0.012863669),
#    ('farc', 0.012215153),
#    ('importante', 0.010845494),
#    ('jaramillo', 0.010836938),
#    ('congreso', 0.010140485)]),
#  (88,
#   [('víctimas', 0.023738239),
#    ('negociación', 0.021216059),
#    ('farc', 0.01844142),
#    ('paso', 0.010688272),
#    ('ley', 0.0098163495),
#    ('sistema', 0.0097781541),
#    ('general', 0.0091474829),
#    ('justicia', 0.0088496748),
#    ('especial', 0.0087524587),
#    ('mesa', 0.0072460715)]),
#  (89,
#   [('hoy', 0.0211059),
#    ('víctimas', 0.018172663),
#    ('colombianos', 0.01378646),
#    ('gran', 0.010744212),
#    ('ley', 0.010200363),
#    ('quiero', 0.0096358731),
#    ('día', 0.0080431495),
#    ('pueblo', 0.0076957494),
#    ('alfonso', 0.0075583179),
#    ('justicia', 0.0071493126)]),
#  (90,
#   [('desarrollo', 0.018775648),
#    ('programas', 0.018682651),
#    ('final', 0.017180631),
#    ('participación', 0.0163879),
#    ('puntos', 0.01601569),
#    ('mesa', 0.015131454),
#    ('implementación', 0.014737792),
#    ('acordado', 0.013782367),
#    ('mecanismos', 0.013756576),
#    ('armas', 0.012784319)]),
#  (91,
#   [('negociación', 0.014426928),
#    ('víctimas', 0.010243156),
#    ('farc', 0.010157377),
#    ('mesa', 0.0079487991),
#    ('general', 0.0079307687),
#    ('agenda', 0.0076417439),
#    ('marco', 0.0071332562),
#    ('fase', 0.0071022594),
#    ('conversaciones', 0.0069381939),
#    ('desarrollo', 0.0068850955)]),
#  (92,
#   [('exploratorio', 0.046385765),
#    ('plenipotenciario', 0.036576148),
#    ('primera', 0.032853153),
#    ('armado', 0.031767763),
#    ('marco', 0.030827144),
#    ('interno', 0.030318862),
#    ('jaramillo', 0.025311971),
#    ('salida', 0.02333012),
#    ('partes', 0.023277592),
#    ('acta', 0.02234266)]),
#  (93,
#   [('farc', 0.021014903),
#    ('delegados', 0.01316923),
#    ('social', 0.013152721),
#    ('desarrollo', 0.011947528),
#    ('venezuela', 0.011840321),
#    ('participación', 0.010957381),
#    ('exploratorio', 0.01081327),
#    ('reconciliación', 0.010571366),
#    ('colombiano', 0.0094501432),
#    ('mesa', 0.009261081)]),
#  (94,
#   [('farc', 0.020305345),
#    ('gran', 0.011878847),
#    ('negociación', 0.010722291),
#    ('desarrollo', 0.010029594),
#    ('colombianos', 0.0094752833),
#    ('fuerzas', 0.0090312501),
#    ('hoy', 0.0085830288),
#    ('seguridad', 0.0084833698),
#    ('víctimas', 0.0084822737),
#    ('paso', 0.0082807951)]),
#  (95,
#   [('colombianos', 0.016447406),
#    ('hoy', 0.012265021),
#    ('desarrollo', 0.0091688186),
#    ('farc', 0.0077904798),
#    ('mesa', 0.0074424618),
#    ('fuerzas', 0.0072984649),
#    ('conversaciones', 0.0071885553),
#    ('gran', 0.0070550074),
#    ('quiero', 0.0070366906),
#    ('violencia', 0.0067743207)]),
#  (96,
#   [('programas', 0.022501871),
#    ('participación', 0.019769678),
#    ('desarrollo', 0.018868648),
#    ('final', 0.017455671),
#    ('marco', 0.014296126),
#    ('mecanismos', 0.01423778),
#    ('puntos', 0.012418356),
#    ('garantías', 0.01203897),
#    ('seguridad', 0.01084834),
#    ('vida', 0.010722657)]),
#  (97,
#   [('agenda', 0.014498816),
#    ('negociación', 0.014122029),
#    ('objetivo', 0.013307811),
#    ('farc', 0.010178038),
#    ('temas', 0.0096416324),
#    ('seguridad', 0.008887927),
#    ('participación', 0.0085860379),
#    ('víctimas', 0.0078576552),
#    ('marco', 0.00763326),
#    ('equipo', 0.0074075218)]),
#  (98,
#   [('noruega', 0.01861449),
#    ('fase', 0.014999605),
#    ('negociación', 0.013672058),
#    ('agenda', 0.013636786),
#    ('delegación', 0.012835073),
#    ('general', 0.01084474),
#    ('mesa', 0.010306342),
#    ('oslo', 0.00996501),
#    ('comisionado', 0.009625636),
#    ('pública', 0.0085690562)]),
#  (99,
#   [('víctimas', 0.015930647),
#    ('años', 0.011107436),
#    ('hoy', 0.0085196095),
#    ('negociación', 0.0083784722),
#    ('mundo', 0.0081624258),
#    ('farc', 0.0080192555),
#    ('general', 0.0078406781),
#    ('primera', 0.0067483904),
#    ('ley', 0.0066717649),
#    ('agenda', 0.0064709247)])]

# %% [markdown]
# #### Association document-topics

# %%
corpus = lda_best_topics[1][2]
for doc in corpus:
    print(doc)
# Out:
# [(54, 0.99673271)]
# [(2, 0.044665169), (20, 0.033743046), (60, 0.83309066), (82, 0.01972905), (93, 0.050558787)]
# [(57, 0.23077063), (76, 0.75342292)]
# [(2, 0.11798243), (6, 0.045397252), (17, 0.08273299), (20, 0.05890942), (25, 0.063138582), (34, 0.076957859), (39, 0.052816395), (43, 0.010576108), (54, 0.082798593), (59, 0.018047627), (60, 0.12912481), (77, 0.21283244), (92, 0.016223356), (93, 0.019003602)]
# [(34, 0.9930281)]
# [(20, 0.87713802), (80, 0.12125546)]
# [(67, 0.98714286)]
# [(25, 0.99589211)]
# [(20, 0.016903166), (41, 0.28414685), (54, 0.074459374), (60, 0.022531917), (65, 0.57187194)]
# [(2, 0.073010653), (17, 0.15234599), (20, 0.090350166), (55, 0.44309044), (59, 0.024978546), (67, 0.054867692), (70, 0.15798695)]
# [(70, 0.98349994)]
# [(6, 0.47893724), (17, 0.16948582), (59, 0.064065687), (70, 0.28189719)]
# [(63, 0.9943428)]
# [(59, 0.98643839)]
# [(2, 0.012056808), (25, 0.018005235), (41, 0.036852323), (54, 0.72699249), (81, 0.16277973), (93, 0.036786981)]
# [(17, 0.59160578), (34, 0.22878708), (93, 0.17403239)]
# [(17, 0.99504995)]
# [(15, 0.65517473), (17, 0.070981845), (53, 0.26719964)]
# [(17, 0.9966327)]
# [(2, 0.13474326), (17, 0.046912003), (25, 0.015112712), (55, 0.28258064), (60, 0.49312457), (96, 0.025474465)]
# [(2, 0.095889404), (20, 0.074168675), (25, 0.023902405), (41, 0.090485193), (43, 0.027063694), (54, 0.1018464), (59, 0.011069934), (60, 0.32979137), (67, 0.027018663), (93, 0.21615632)]
# [(41, 0.89832896), (93, 0.099397235)]
# [(92, 0.987625)]
# [(43, 0.48642573), (55, 0.036209945), (93, 0.42515859), (96, 0.050547741)]
# [(96, 0.9965018)]
# [(39, 0.99543774)]
# [(2, 0.3742252), (39, 0.038649224), (93, 0.5843932)]
# [(2, 0.92407602), (60, 0.073829912)]
# [(17, 0.019120032), (20, 0.010640883), (24, 0.20628208), (25, 0.036976911), (39, 0.019909665), (43, 0.016390154), (59, 0.010629828), (65, 0.20241311), (67, 0.022139758), (82, 0.35371897), (93, 0.10042189)]
# [(6, 0.031236371), (30, 0.028954362), (40, 0.44840783), (41, 0.033343866), (59, 0.010415051), (60, 0.20651007), (65, 0.18823786), (80, 0.036342405)]
# [(85, 0.97524995)]
# [(54, 0.058798335), (87, 0.9360708)]
# [(2, 0.19046393), (20, 0.074205369), (43, 0.22209056), (54, 0.0724805), (59, 0.018113246), (67, 0.010246678), (93, 0.41012126)]
# [(2, 0.76245028), (41, 0.19764158), (96, 0.035785977)]
# [(62, 0.99700004)]

# %% [markdown]
# #### Topics sorted by recurrence

# %%
total_weights = defaultdict(float)
for doc in corpus:
    for topic, weight in doc:
        total_weights[topic] += abs(weight)
total_weights = dict(total_weights)

# %%
Counter(total_weights).most_common()
# Out:
# [(17, 3.1244077254086733),
#  (2, 2.7160263359546661),
#  (54, 2.1148478537797928),
#  (93, 2.1090674083679914),
#  (60, 2.0912751704454422),
#  (41, 1.5464098192751408),
#  (70, 1.4233634769916534),
#  (34, 1.2986726015806198),
#  (20, 1.2376726446673274),
#  (25, 1.1556511064991355),
#  (59, 1.1440475583076477),
#  (39, 1.1064300257712603),
#  (96, 1.1050218716263771),
#  (67, 1.1013595480471849),
#  (92, 1.0036254096776247),
#  (62, 0.99700003862380981),
#  (63, 0.99434280395507812),
#  (85, 0.97524994611740112),
#  (65, 0.96176449954509735),
#  (87, 0.93601882457733154),
#  (43, 0.76728417631238699),
#  (55, 0.76269321888685226),
#  (76, 0.75283116102218628),
#  (15, 0.66009402275085449),
#  (6, 0.55159792490303516),
#  (40, 0.45285332202911377),
#  (82, 0.37025244906544685),
#  (53, 0.26204594969749451),
#  (57, 0.23136238753795624),
#  (77, 0.21516917645931244),
#  (24, 0.20858719944953918),
#  (81, 0.1618371456861496),
#  (80, 0.15548631548881531),
#  (30, 0.026036109775304794)]

# %% [markdown]
# ### HDP

# %% [markdown]
# #### Topics

# %%
hdp_best_topics[1][0]
# Out:
# [(0,
#   [('mesa', 0.0075346773828548277),
#    ('fase', 0.0051975000963632298),
#    ('conversaciones', 0.0049505642434960985),
#    ('agenda', 0.00486544241929568),
#    ('general', 0.004844063991800188),
#    ('diálogo', 0.0045111058902907383),
#    ('noruega', 0.0043126942813266501),
#    ('delegados', 0.0042413638479691478),
#    ('agosto', 0.0039877273342128353),
#    ('jaramillo', 0.0038794211596285279)]),
#  (1,
#   [('desarrollo', 0.0055187465428750476),
#    ('gran', 0.0054166570017025444),
#    ('hoy', 0.0051105905410830238),
#    ('colombianos', 0.0049448370964122242),
#    ('exploratorio', 0.004139841714708545),
#    ('seguridad', 0.0038930326825079055),
#    ('social', 0.0035023685209391356),
#    ('vida', 0.0033652822808889994),
#    ('mundo', 0.0033367307861352281),
#    ('fuerzas', 0.0032790124686234586)]),
#  (2,
#   [('negociación', 0.012126821911735374),
#    ('farc', 0.00970372253076319),
#    ('víctimas', 0.0074994395105206424),
#    ('sistema', 0.0042129006490405144),
#    ('paso', 0.0035948127365890525),
#    ('justicia', 0.0035905472449125784),
#    ('posible', 0.0033564415218547633),
#    ('general', 0.0033398183246437464),
#    ('apoyo', 0.0031774879136116283),
#    ('propuestas', 0.0030932324058351394)]),
#  (3,
#   [('mesa', 0.011744487686203869),
#    ('mauricio', 0.0041214603288369745),
#    ('desarrollo', 0.0038668032730126054),
#    ('pregunta', 0.003630630922432486),
#    ('marco', 0.0035223837197822711),
#    ('tema', 0.0035041302956931868),
#    ('participación', 0.0034992649402138245),
#    ('jaramillo', 0.0034816275138558309),
#    ('pueblo', 0.0034555542000936938),
#    ('delegación', 0.0033047417544533704)]),
#  (4,
#   [('víctimas', 0.016533477631617985),
#    ('ley', 0.011368474322933819),
#    ('reparación', 0.0070613961942798476),
#    ('hoy', 0.0064261126302622281),
#    ('sociedad', 0.0044846590702788021),
#    ('tierras', 0.0041281785428727369),
#    ('atención', 0.0035037780918442526),
#    ('historia', 0.0033360986901586273),
#    ('justicia', 0.0032163927074899219),
#    ('colombianos', 0.0031285573098464104)]),
#  (5,
#   [('equipo', 0.0060567925985150805),
#    ('trabajo', 0.0040447125528124718),
#    ('negociadores', 0.0036882675003743781),
#    ('fase', 0.0035303171248717187),
#    ('general', 0.0031769652519817791),
#    ('mesa', 0.0030645181146658389),
#    ('forma', 0.0029086767455139464),
#    ('patria', 0.0028261072180716953),
#    ('doctor', 0.002776206664206496),
#    ('social', 0.0026493835756357022)]),
#  (6,
#   [('agenda', 0.0096396969874598514),
#    ('temas', 0.0057497479878556596),
#    ('objetivo', 0.005196425401073285),
#    ('seguridad', 0.0042871045244308277),
#    ('armado', 0.0039029228688781678),
#    ('internacionales', 0.0036487642056176085),
#    ('partes', 0.0036021115392715739),
#    ('final', 0.0035588614831627849),
#    ('marco', 0.0033618567151743888),
#    ('garantes', 0.0029626106140506485)]),
#  (7,
#   [('internacional', 0.0038835306933174634),
#    ('ejemplo', 0.0037985981660666281),
#    ('ver', 0.0034368545046866389),
#    ('seguridad', 0.0034348979582200785),
#    ('lucha', 0.0032772483778310941),
#    ('años', 0.003065512018865223),
#    ('discusión', 0.00289761920178957),
#    ('armado', 0.0028245879291725015),
#    ('temas', 0.0026810686996376039),
#    ('caso', 0.0026539463936040308)]),
#  (8,
#   [('farc', 0.020125048800956561),
#    ('zona', 0.013038786796305843),
#    ('dei', 0.0096560202149972105),
#    ('carlos', 0.0081984186578444689),
#    ('señor', 0.0072428564456688818),
#    ('restrepo', 0.006592947947957813),
#    ('actores', 0.0065212871118092907),
#    ('uribe', 0.0063629092891095149),
#    ('importantes', 0.0061138058336854834),
#    ('humanitario', 0.0061062434900784404)]),
#  (9,
#   [('farc', 0.0092945186159057724),
#    ('venezuela', 0.005845515516214048),
#    ('delegados', 0.0046800226804651389),
#    ('partes', 0.0043267863419282028),
#    ('hoy', 0.0038816751512001971),
#    ('garantes', 0.0035961089571178643),
#    ('diferente', 0.0032811797897362646),
#    ('conversaciones', 0.0032744730816183358),
#    ('colombianos', 0.0032464501401807465),
#    ('fase', 0.0031412258914578022)]),
#  (10,
#   [('programas', 0.0073432676736026933),
#    ('desarrollo', 0.0071174825613395751),
#    ('participación', 0.0062198801283252052),
#    ('social', 0.0052269481452696326),
#    ('marco', 0.005066205438536934),
#    ('acceso', 0.0040257446950180548),
#    ('mecanismos', 0.0037846517155839987),
#    ('derechos', 0.0031353976941018908),
#    ('guerra', 0.0028488444980968434),
#    ('planes', 0.0027971215175150643)]),
#  (11,
#   [('plataforma', 0.011168218432679518),
#    ('farc', 0.0094826126020313081),
#    ('abril', 0.0075246465689746238),
#    ('carta', 0.0074029128549159412),
#    ('central', 0.0069931684995091746),
#    ('reconciliación', 0.0067000475152497714),
#    ('reconstrucción', 0.0064749670718082268),
#    ('dela', 0.0063636042047198749),
#    ('social', 0.0057399936911175882),
#    ('lucha', 0.0055910354069493755)]),
#  (12,
#   [('mundo', 0.0049452869029362537),
#    ('años', 0.0047467981299435438),
#    ('víctimas', 0.0035380282716155325),
#    ('guerra', 0.002756871691667493),
#    ('solución', 0.0026708749040183564),
#    ('forma', 0.0022771659706199523),
#    ('diálogo', 0.002139174733864331),
#    ('dejar', 0.0020721651654406208),
#    ('farc', 0.0020634972210254194),
#    ('apoyo', 0.0020498921414518708)]),
#  (13,
#   [('participación', 0.0055050823775634541),
#    ('agenda', 0.0054211937800496494),
#    ('fase', 0.0050317420567469384),
#    ('acuerdos', 0.0045768073282515063),
#    ('puntos', 0.0044331269178147998),
#    ('trata', 0.00443171518267527),
#    ('final', 0.00436121481801428),
#    ('acordado', 0.0041095568378293861),
#    ('mesa', 0.0038642612601283511),
#    ('implementación', 0.0030114553275851323)]),
#  (14,
#   [('delegados', 0.011865332617517739),
#    ('venezuela', 0.0090378028231078433),
#    ('partes', 0.0081372276520842654),
#    ('cicr', 0.0070788631976781832),
#    ('delegado', 0.0059584157965642467),
#    ('noruega', 0.0054904268328663536),
#    ('traslado', 0.0049242878311443021),
#    ('febrero', 0.0045463488885289574),
#    ('gobiernos', 0.0045359170588086944),
#    ('exploratorio', 0.0043295419157010039)]),
#  (15,
#   [('secreto', 0.0068807476242494382),
#    ('pablo', 0.0050243973616177062),
#    ('catatumbo', 0.0046836203332746296),
#    ('alfonso', 0.0039256774894751737),
#    ('cano', 0.0038669999435694373),
#    ('delegados', 0.0037919162633456059),
#    ('propuesta', 0.0030850897697757601),
#    ('acosta', 0.0029106164382338242),
#    ('mensaje', 0.0027930423667978537),
#    ('amigo', 0.0027708895890774404)]),
#  (16,
#   [('delegados', 0.0031077581219708965),
#    ('gran', 0.0028467975176126171),
#    ('abrazo', 0.0027974721525130613),
#    ('frontera', 0.0025347798973836483),
#    ('primer', 0.0024817238592741071),
#    ('enero', 0.0023593872023095087),
#    ('incorporados', 0.0023102766875415285),
#    ('mensaje', 0.002183976809716842),
#    ('pablo', 0.0021443020965287922),
#    ('habló', 0.0021422615650470121)]),
#  (17,
#   [('febrero', 0.0032695468577778439),
#    ('farc', 0.0031776417906705491),
#    ('fecha', 0.0031335418931638212),
#    ('sitio', 0.002678994060954763),
#    ('pablo', 0.0026363105017569227),
#    ('momento', 0.0024674707134142359),
#    ('cuenta', 0.0024282379245835527),
#    ('información', 0.0024192272189777464),
#    ('mensajes', 0.0023530501122530217),
#    ('negociación', 0.0023330712577657314)]),
#  (18,
#   [('general', 0.008013798533580762),
#    ('estable', 0.0051976781564110194),
#    ('duradera', 0.004594875437851865),
#    ('terminación', 0.0044661286342045211),
#    ('delegaciones', 0.00445902280972985),
#    ('construcción', 0.0043997396493072041),
#    ('firma', 0.0037228898408982396),
#    ('noruega', 0.0036418837607362742),
#    ('mesa', 0.0034766979762291803),
#    ('países', 0.0033954609723199584)]),
#  (19,
#   [('pueblo', 0.0045927602400000732),
#    ('comandante', 0.0041741209741123523),
#    ('alfonso', 0.0037897446721031109),
#    ('combate', 0.0030502484664336883),
#    ('prácticamente', 0.002904844465419621),
#    ('nueva', 0.0025762790293046896),
#    ('cano', 0.0024834392877237637),
#    ('vencer', 0.002364510706664589),
#    ('militar', 0.0022233397377553837),
#    ('victoria', 0.0021813119983068673)]),
#  (20,
#   [('delegados', 0.0093698242808353451),
#    ('traslado', 0.0057280402007589427),
#    ('venezuela', 0.0051791001032851971),
#    ('noruega', 0.0039700619949870446),
#    ('acta', 0.0037879460587370126),
#    ('acercamientos', 0.0028640100620026506),
#    ('miembro', 0.0028408838628420792),
#    ('garantes', 0.0028059239904135191),
#    ('gobiernos', 0.0027938161777289732),
#    ('orchila', 0.0025661219038686932)]),
#  (21,
#   [('paso', 0.0055876081767167914),
#    ('buena', 0.0043477106912081362),
#    ('equipo', 0.0040602563818950468),
#    ('sergio', 0.003941946442346197),
#    ('años', 0.0036724182538407091),
#    ('doctor', 0.0036391389412033376),
#    ('importante', 0.0033264640599949586),
#    ('congreso', 0.0024235993492395459),
#    ('forma', 0.0023230768651862099),
#    ('suerte', 0.0022858473882972946)]),
#  (22,
#   [('alfonso', 0.0024004837016017798),
#    ('contaminando', 0.0023819839450880259),
#    ('falta', 0.0022743187390391992),
#    ('derrotar', 0.0022651740593678531),
#    ('fortalecer', 0.00201004625638728),
#    ('sol', 0.0019747339377249877),
#    ('carta', 0.0019219649522769328),
#    ('enemigo', 0.0019014942774326757),
#    ('piedad', 0.0018067224137338607),
#    ('cano', 0.0017272368515338595)]),
#  (23,
#   [('lleras', 0.0027392238931094764),
#    ('delegación', 0.0025798423320106648),
#    ('vigente', 0.0022761990548934934),
#    ('segundo', 0.0019916613784195605),
#    ('decreto', 0.0019462287255858988),
#    ('propios', 0.0018680433599125407),
#    ('putumayo', 0.0018163005269653588),
#    ('lograr', 0.0017066173081492608),
#    ('encontrar', 0.0016972395359475801),
#    ('visión', 0.0016945271503846216)]),
#  (24,
#   [('plenipotenciario', 0.0042341146967849594),
#    ('exploratorio', 0.0038454518588258869),
#    ('armado', 0.0031938876392052793),
#    ('marco', 0.0030472851598936086),
#    ('interno', 0.0026665668262346536),
#    ('primera', 0.0026464491596636611),
#    ('frentes', 0.0025657926775952116),
#    ('prolongación', 0.0024046443344513573),
#    ('marzo', 0.0021181688544013345),
#    ('partes', 0.0019921977932232668)]),
#  (25,
#   [('presidencia', 0.0045692182780500421),
#    ('alto', 0.0043623180419653049),
#    ('sergio', 0.0033861169625876166),
#    ('comisionado', 0.0030738028381826561),
#    ('situación', 0.0029370728369346628),
#    ('decreto', 0.0025864074826776702),
#    ('jaramillo', 0.0025297399480428018),
#    ('republica', 0.002447779062142439),
#    ('administrativo', 0.0023835376519158731),
#    ('departamento', 0.0020328261063234316)]),
#  (26,
#   [('propósito', 0.0026074569753468287),
#    ('establecida', 0.0023789440051695844),
#    ('buscar', 0.0022837923236996862),
#    ('construcción', 0.0022151905969218103),
#    ('entender', 0.0021513393781084642),
#    ('llamado', 0.0020714827690884925),
#    ('memorias', 0.0020643002454730441),
#    ('líder', 0.0018960058581751009),
#    ('unirse', 0.0018485533267902452),
#    ('consenso', 0.0018374349685506873)]),
#  (27,
#   [('líneas', 0.0021879535672130125),
#    ('satisfacción', 0.0020955129103688796),
#    ('totalmente', 0.0019163559948261689),
#    ('ninguno', 0.001869606381940559),
#    ('sistemas', 0.0018554969931097931),
#    ('defensa', 0.0018188074004496237),
#    ('hacerlos', 0.0018179618218170492),
#    ('jugarse', 0.0018164445995298556),
#    ('garantizar', 0.0017375346679130729),
#    ('huila', 0.0017041104700783736)]),
#  (28,
#   [('adecuada', 0.0025945032747340985),
#    ('dándoles', 0.0023912856922417595),
#    ('hermes', 0.0023087328305565302),
#    ('garantizando', 0.0020532734020072959),
#    ('discreción', 0.0020472446720647243),
#    ('derogada', 0.002039648605097655),
#    ('hechos', 0.0020369638312633478),
#    ('sufrimiento', 0.0019917515991077096),
#    ('pasión', 0.0019602345080164539),
#    ('reunirse', 0.0019456332110221505)]),
#  (29,
#   [('propuesta', 0.0031868960776753451),
#    ('delegados', 0.0030967016313991754),
#    ('luego', 0.0026197687930527899),
#    ('primer', 0.0023618962750422551),
#    ('cuales', 0.0019968400829835919),
#    ('delos', 0.0019417718140830652),
#    ('garantía', 0.0018857831772602044),
#    ('redistribución', 0.0018750806867163293),
#    ('venir', 0.0017796965940440122),
#    ('foros', 0.001734171082586843)]),
#  (30,
#   [('vocación', 0.0041000531993142554),
#    ('enla', 0.0022795458537822675),
#    ('necesita', 0.0022308311107352421),
#    ('impedido', 0.002058145109823402),
#    ('efectuamos', 0.0019345667126631015),
#    ('continua', 0.0019035421863666285),
#    ('largos', 0.0018089473808688811),
#    ('veces', 0.0017910337199987139),
#    ('termina', 0.0017558593177914206),
#    ('coinciden', 0.0017224917869542355)]),
#  (31,
#   [('movimientos', 0.0023423168948424212),
#    ('decimos', 0.0022017486842859069),
#    ('individual', 0.002008630758881292),
#    ('tratamos', 0.0019704799117771944),
#    ('subsidios', 0.0019265032061552194),
#    ('perdón', 0.0018911914509668257),
#    ('distribución', 0.0018231609704314449),
#    ('reunirse', 0.0017903440676128098),
#    ('redactar', 0.0017583577763275171),
#    ('alternativas', 0.0017419703554414875)]),
#  (32,
#   [('compromisos', 0.0026222133015750891),
#    ('poderosas', 0.0025843712521135655),
#    ('importantes', 0.0023990590502202696),
#    ('seguros', 0.0023765737942769449),
#    ('plomo', 0.0020910587033286057),
#    ('reitera', 0.0018964860344705689),
#    ('través', 0.0018664410706736819),
#    ('simultáneo', 0.0018513352064353447),
#    ('rcn', 0.0017684080785379591),
#    ('resto', 0.0017589957674368504)]),
#  (33,
#   [('debemos', 0.0021055194397258861),
#    ('castrillón', 0.0020894065552654771),
#    ('contactos', 0.0019557063683149152),
#    ('tranquilo', 0.0019454150787968825),
#    ('refuercen', 0.0018696023167294913),
#    ('helicóptero', 0.0017473420957982689),
#    ('sostenible', 0.0016960315848007896),
#    ('clausura', 0.0016885162033996311),
#    ('oportunidad', 0.0016681146330580587),
#    ('avanzado', 0.0016322593393646911)]),
#  (34,
#   [('fronteriza', 0.0023730333930206239),
#    ('representa', 0.0022101886891537246),
#    ('mayoría', 0.002056841311425613),
#    ('grande', 0.0020502245987456861),
#    ('coyuntura', 0.0020107041059740207),
#    ('mensaje', 0.0019869003311795007),
#    ('definir', 0.0019253192601319626),
#    ('oficiales', 0.0018388934787085575),
#    ('pensar', 0.0018232567846490557),
#    ('confiamos', 0.0018086112921940672)]),
#  (35,
#   [('principio', 0.0029604073745216888),
#    ('aparato', 0.0019434886672149917),
#    ('comentarios', 0.0019169221185580229),
#    ('incorporación', 0.0018328868626309252),
#    ('buscando', 0.0016936469881491786),
#    ('nombre', 0.001692107000316067),
#    ('adelantar', 0.0016635126490773401),
#    ('través', 0.0016596053334540528),
#    ('fruto', 0.001650132768228021),
#    ('esclarecerá', 0.0016453544860458716)]),
#  (36,
#   [('recibiendo', 0.002713235052719871),
#    ('puestos', 0.0026950434174124412),
#    ('presentada', 0.0021391258032795071),
#    ('vuelve', 0.0021287392946331856),
#    ('verá', 0.0019861425657105073),
#    ('tercero', 0.0019341406186311578),
#    ('anunciado', 0.0019056505888094574),
#    ('suceda', 0.0018967588908648076),
#    ('daño', 0.0018946808224316412),
#    ('decenas', 0.0018093607263753547)]),
#  (37,
#   [('despeje', 0.0018282293129604581),
#    ('débiles', 0.0018097858351532458),
#    ('permanente', 0.0018010449340280122),
#    ('pasos', 0.0017787813357626908),
#    ('café', 0.0017710156337939686),
#    ('golpes', 0.0017258185332202946),
#    ('estructuras', 0.0017140488823375098),
#    ('reunirme', 0.0017117601694184581),
#    ('definió', 0.0016882670953213162),
#    ('podria', 0.0016791231934947259)]),
#  (38,
#   [('establecida', 0.002300233915686093),
#    ('jugar', 0.0022655282457098359),
#    ('permita', 0.0020875027790483022),
#    ('especialmente', 0.0020014443367336833),
#    ('esperaba', 0.0019646131155093205),
#    ('problemas', 0.0019470933762422396),
#    ('defensa', 0.0018496607463128543),
#    ('alma', 0.0018322153227558413),
#    ('transcurso', 0.0017662458348436088),
#    ('guerrillas', 0.0017375393712910526)]),
#  (39,
#   [('generó', 0.0024830805630582787),
#    ('necesarios', 0.0023280278179512053),
#    ('ilícitas', 0.0022961364084577345),
#    ('unilateral', 0.0020545314641485534),
#    ('escuadrones', 0.0019051386053882461),
#    ('quinto', 0.0019042568504321984),
#    ('potestad', 0.0018919291723926565),
#    ('pienso', 0.0018496162399488389),
#    ('inútil', 0.0018484201930658187),
#    ('coordinación', 0.0018279300077253227)]),
#  (40,
#   [('mando', 0.0027527813550590622),
#    ('necesidad', 0.0025679287807586467),
#    ('secretas', 0.0023663477932407443),
#    ('vía', 0.0022319046442737167),
#    ('oficina', 0.0021319600939581373),
#    ('contribuya', 0.0020553663483102412),
#    ('cálido', 0.0019586506117325363),
#    ('inútil', 0.0019526043454676052),
#    ('delante', 0.0019298634126388022),
#    ('personal', 0.0019296548522320959)]),
#  (41,
#   [('señala', 0.0025554441041564721),
#    ('carlos', 0.0024486944534841651),
#    ('vocación', 0.0024176044823245721),
#    ('partido', 0.0021768440971459717),
#    ('razones', 0.0021224066865737721),
#    ('entiendan', 0.0021091017821922671),
#    ('setenta', 0.002062522707115504),
#    ('llegado', 0.0020213646145413895),
#    ('sector', 0.0019549212932152248),
#    ('argumentos', 0.0018462616553493879)]),
#  (42,
#   [('repetirlos', 0.0021004846111953119),
#    ('jesús', 0.0019809359202194302),
#    ('partimos', 0.0019370736754389724),
#    ('horizonte', 0.0019018112894674841),
#    ('verá', 0.0018797463809671726),
#    ('manifestarles', 0.001822259621870314),
#    ('entera', 0.0017806502003644858),
#    ('despeje', 0.0017766302701156397),
#    ('diciendo', 0.0017400690998631769),
#    ('muestra', 0.0017051166306412365)]),
#  (43,
#   [('mírez', 0.0023856215850261027),
#    ('inútil', 0.0023470988866222246),
#    ('intentos', 0.002339677894805397),
#    ('enriquecido', 0.0022391148324089876),
#    ('combatiendo', 0.0021553430557578494),
#    ('artículo', 0.0021226966618500425),
#    ('riqueza', 0.0020870598800185268),
#    ('multinacionales', 0.0019666935686062296),
#    ('antonio', 0.0017761942862856007),
#    ('incertidumbre', 0.0017751559383630722)]),
#  (44,
#   [('conocer', 0.0021330513818994157),
#    ('viaje', 0.0020992439447682842),
#    ('terminación', 0.0020237572191891063),
#    ('viajaron', 0.0019592613204405217),
#    ('trabajadores', 0.0019175011340191849),
#    ('resolución', 0.0018517111379969798),
#    ('fondo', 0.0018271185829637922),
#    ('rojas', 0.0018204465522115231),
#    ('fallidos', 0.0017837787790146789),
#    ('alimentaria', 0.0017696011173368119)]),
#  (45,
#   [('testigos', 0.0022241513749483733),
#    ('john', 0.0021659279089418339),
#    ('firmó', 0.0019584673371400522),
#    ('buenas', 0.0019438852400652253),
#    ('temas', 0.0019433767716945248),
#    ('diciembre', 0.0019054880615529503),
#    ('constitucional', 0.0017810841374779941),
#    ('prolongación', 0.0017782240635008594),
#    ('nace', 0.0017038394745697032),
#    ('querido', 0.0016983290130848855)]),
#  (46,
#   [('contenidos', 0.0021663597132452637),
#    ('cabida', 0.0020740402928657612),
#    ('sueñan', 0.0020322620196660413),
#    ('duradera', 0.0020170932406059542),
#    ('barreras', 0.0019969980968190418),
#    ('recuerdo', 0.0019886490866896363),
#    ('cuenta', 0.0019805412876864933),
#    ('comienza', 0.0019544913678005787),
#    ('flexible', 0.0018893368384419727),
#    ('julio', 0.0018822124628031886)]),
#  (47,
#   [('mantienen', 0.0033726033942249236),
#    ('principio', 0.0031300020214868932),
#    ('firmó', 0.0022306275088523654),
#    ('deberán', 0.0021112648424769227),
#    ('palabras', 0.001857736330188693),
#    ('falsas', 0.0018142149775604145),
#    ('utilizaron', 0.0018024891173784854),
#    ('emprender', 0.0017800043598696594),
#    ('mantendrá', 0.0017692938573478439),
#    ('finalmente', 0.0017644398865791304)]),
#  (48,
#   [('establecerán', 0.0027131622880134753),
#    ('trabajar', 0.002383838268055044),
#    ('aceptación', 0.0022140236424944876),
#    ('enriquecido', 0.0021458305152906904),
#    ('cualquiera', 0.0020410412491372299),
#    ('inicia', 0.0019750409590367445),
#    ('establecerá', 0.001965743655935688),
#    ('deber', 0.0019511394629070388),
#    ('presentado', 0.0019366415723391834),
#    ('órganos', 0.001910384825283248)]),
#  (49,
#   [('histórica', 0.0024200956636524396),
#    ('lenguaje', 0.0021939353523644511),
#    ('semanas', 0.0021628741357299763),
#    ('pagar', 0.0020826894269109662),
#    ('gestión', 0.0020499320875978543),
#    ('numeral', 0.0019765310461732181),
#    ('operación', 0.001935093501991189),
#    ('consecuencias', 0.0018869768087669144),
#    ('tierra', 0.001883511277961765),
#    ('tratamos', 0.001850063571137134)]),
#  (50,
#   [('arreglar', 0.002374236240831001),
#    ('entregar', 0.0023244053927135334),
#    ('venciendo', 0.0022918648664981885),
#    ('adelantado', 0.0021239926533508668),
#    ('volvamos', 0.0020560536308351762),
#    ('abordan', 0.0020014273003022666),
#    ('caso', 0.0019720352969900038),
#    ('deroga', 0.0019377680906952086),
#    ('bajar', 0.0019156668258408195),
#    ('imposible', 0.0019120773978759406)]),
#  (51,
#   [('vicente', 0.0025864792104810467),
#    ('económicos', 0.0024044597961423576),
#    ('cruz', 0.0022856538904515171),
#    ('revisión', 0.0022003685589684413),
#    ('llanos', 0.0021382970378488035),
#    ('gremios', 0.0020242526474357277),
#    ('rural', 0.0020050111954052971),
#    ('aceptado', 0.0019485683508066484),
#    ('requiere', 0.0018673376492132482),
#    ('dará', 0.0018449858269277894)]),
#  (52,
#   [('sistema', 0.0022213737991956463),
#    ('llanos', 0.0021889125429511995),
#    ('absolutamente', 0.0021416029843571364),
#    ('sector', 0.0021158897839395701),
#    ('exclusivamente', 0.0019637833933712303),
#    ('recibiendo', 0.0019175593796651629),
#    ('paramilitar', 0.0017577537465552828),
#    ('detallado', 0.0017370069020704933),
#    ('internos', 0.0016761532008556751),
#    ('castrillón', 0.0016447998902736545)]),
#  (53,
#   [('esenciales', 0.0034691583533359906),
#    ('principal', 0.0028810567368304295),
#    ('ayerbe', 0.0021851775517679893),
#    ('operación', 0.0021588082220236186),
#    ('pregunta', 0.0021306894945030404),
#    ('conversar', 0.0020802031256116934),
#    ('patiño', 0.0020484267031473701),
#    ('seguirán', 0.0020335670375518579),
#    ('logro', 0.0020071401161573265),
#    ('productivas', 0.0018937144044490362)]),
#  (54,
#   [('esfuerzo', 0.0023086054181011098),
#    ('ingreso', 0.0021518327526150877),
#    ('camilo', 0.0021257727959254815),
#    ('trascendencia', 0.0018743974953207008),
#    ('invitar', 0.0018388722062211179),
#    ('profundas', 0.0018208088006152641),
#    ('cerca', 0.0017532179763212795),
#    ('considerado', 0.0017139304846961337),
#    ('obrando', 0.0016987086339716349),
#    ('inmensa', 0.0016715894433534596)]),
#  (55,
#   [('penal', 0.0028765223677436605),
#    ('tercero', 0.0020854450374568827),
#    ('dará', 0.0019682911262941462),
#    ('venezolana', 0.0019485872667326207),
#    ('largo', 0.0018411873407082674),
#    ('pareció', 0.0017775606138610914),
#    ('radicalmente', 0.0017760590675463129),
#    ('serios', 0.0017744204087592301),
#    ('urgente', 0.0017573837451804186),
#    ('concluyó', 0.001743081678790163)]),
#  (56,
#   [('básicas', 0.0030041528817122912),
#    ('fijar', 0.0024317341461882356),
#    ('vía', 0.0023971262741408999),
#    ('diga', 0.0023941044509904752),
#    ('quisiera', 0.0023781392869300011),
#    ('detrás', 0.0020739666228929273),
#    ('camaradas', 0.001883556267537359),
#    ('rueda', 0.0018835184765411807),
#    ('incentivos', 0.0018087860090930806),
#    ('veo', 0.0018069122218132294)]),
#  (57,
#   [('pasada', 0.0030708216876885403),
#    ('encargó', 0.0026435647334717761),
#    ('periódicas', 0.0026142800782776548),
#    ('problema', 0.0023865566270666648),
#    ('manifestaciones', 0.002207106300180148),
#    ('expectativas', 0.0021946037494580163),
#    ('comprometió', 0.0018641559919138843),
#    ('libertad', 0.0018294005048176503),
#    ('periferia', 0.0018089550663441883),
#    ('salidas', 0.0017854143648499171)]),
#  (58,
#   [('firmeza', 0.0029685855629694169),
#    ('quedarnos', 0.0028069011750808956),
#    ('premio', 0.0024042244909524431),
#    ('den', 0.0023806244083980745),
#    ('generó', 0.0021361905912432068),
#    ('cuántos', 0.0020929969683353587),
#    ('llama', 0.0019564713599129484),
#    ('mercados', 0.0019075059002110443),
#    ('normal', 0.0018074600604862617),
#    ('mes', 0.0017711995778315756)]),
#  (59,
#   [('ininterrumpidas', 0.00259905252217159),
#    ('pueblos', 0.0024545768143412017),
#    ('historia', 0.0022908086905887182),
#    ('combatimos', 0.0021858536131430131),
#    ('pocos', 0.0020282342451452971),
#    ('castrillón', 0.0019818147115432689),
#    ('motivos', 0.00197704673715275),
#    ('constructiva', 0.0019185520537484415),
#    ('definir', 0.0018601641349946117),
#    ('ciudad', 0.001841075556282512)]),
#  (60,
#   [('incluimos', 0.0023857394913105717),
#    ('preparar', 0.0022402984070476087),
#    ('reunirse', 0.0021301122762166849),
#    ('eficacia', 0.0021180269558692352),
#    ('frontera', 0.0020905129209594503),
#    ('vulnerables', 0.002067569121216562),
#    ('eventual', 0.0019320099271410078),
#    ('vigente', 0.0018536967698728664),
#    ('produce', 0.0017577774525508385),
#    ('marzo', 0.0017302969144651888)]),
#  (61,
#   [('podía', 0.0028979219713353103),
#    ('anexo', 0.0024528879847051984),
#    ('mencionan', 0.0021908433941537318),
#    ('fuentes', 0.0019738201796204069),
#    ('experiencia', 0.0019458811219283437),
#    ('reservas', 0.0019064601411510603),
#    ('armados', 0.0018552133688651035),
#    ('declaraciones', 0.0017361313510311296),
#    ('delos', 0.0017041483202565023),
#    ('subsumir', 0.0017033282976687189)]),
#  (62,
#   [('mas', 0.0023733807519516728),
#    ('parcelas', 0.0023324245638630748),
#    ('vida', 0.0022404553697053142),
#    ('oratoria', 0.0022022577173457848),
#    ('diversos', 0.0020943243828884972),
#    ('correcto', 0.0019566618983880932),
#    ('tipos', 0.0018755892711539951),
#    ('declaración', 0.001837507891583717),
#    ('militares', 0.0018260165460763521),
#    ('determinante', 0.0017846975425870886)]),
#  (63,
#   [('ilumine', 0.0031059445501600762),
#    ('campaña', 0.0025735427035464475),
#    ('capaz', 0.0023026051639977916),
#    ('cuya', 0.0022104518110649617),
#    ('chávez', 0.002165506647608762),
#    ('metiendo', 0.0020803794469316053),
#    ('negocio', 0.0020256437406262089),
#    ('largas', 0.0019790879956234427),
#    ('valiente', 0.0019420926644454824),
#    ('tratamos', 0.0019272711502518706)]),
#  (64,
#   [('continuar', 0.0030235490823020839),
#    ('señor', 0.0020642318137213526),
#    ('casa', 0.0019988158575651566),
#    ('insurgencia', 0.0019969887425646347),
#    ('expresarse', 0.0019440547387423474),
#    ('acto', 0.0018926471245307816),
#    ('desmovilización', 0.0018357335819909567),
#    ('emblemas', 0.0017954565446504831),
#    ('ámbitos', 0.0017791510951511358),
#    ('ejecutivo', 0.0017343177228200907)]),
#  (65,
#   [('instrumentos', 0.0041493457385849081),
#    ('presos', 0.0027010006628987644),
#    ('serie', 0.0023371860707736402),
#    ('diferencias', 0.002165628627651987),
#    ('intermediarios', 0.002127519199360813),
#    ('agrarios', 0.0020003779824404292),
#    ('agenda', 0.0019227282895340242),
#    ('concreta', 0.0019181862979436074),
#    ('acá', 0.0018868204439972983),
#    ('torno', 0.001814555202246178)]),
#  (66,
#   [('libertador', 0.0023921038403981903),
#    ('desa', 0.0019039614330501676),
#    ('cambio', 0.0018781834267811348),
#    ('creciendo', 0.0018740925533154221),
#    ('método', 0.0018632652709453415),
#    ('públicos', 0.0017834204167908319),
#    ('profesionalismo', 0.0017614561181896219),
#    ('extracción', 0.0017603298871876095),
#    ('perfecto', 0.0017356631708488749),
#    ('occidental', 0.001708990337204298)]),
#  (67,
#   [('publíquese', 0.0034243801170502335),
#    ('darnos', 0.0021202603240228555),
#    ('alternos', 0.0020702153102119545),
#    ('democrático', 0.0020086178064789577),
#    ('millón', 0.0019706928680878672),
#    ('metodología', 0.0019224585489553843),
#    ('penas', 0.0018931413343858932),
#    ('bombardeo', 0.0018468293053766941),
#    ('realizada', 0.0018332326474118463),
#    ('comprender', 0.0018318563928428706)]),
#  (68,
#   [('estrategia', 0.002336861179134073),
#    ('agencia', 0.0022608879321584247),
#    ('camarada', 0.0021822350553437793),
#    ('lozano', 0.0021314786882301734),
#    ('discutir', 0.0020534743038451179),
#    ('acorten', 0.0019853534649361044),
#    ('compromisos', 0.001929867819618157),
#    ('manos', 0.0018637396285118197),
#    ('avendaño', 0.0018525223335111346),
#    ('alvaro', 0.0018045172684446581)]),
#  (69,
#   [('colombianas', 0.002719320447782544),
#    ('debía', 0.0024385556809030915),
#    ('aunque', 0.0024077097420285827),
#    ('edad', 0.0022920251154613241),
#    ('comenzó', 0.0022514421828614883),
#    ('comunidad', 0.0021510184086205746),
#    ('primera', 0.0021329295424828143),
#    ('significado', 0.0019901210232865082),
#    ('humano', 0.0018701503175111293),
#    ('generaciones', 0.0018134524895464948)]),
#  (70,
#   [('consensos', 0.0024413172434499847),
#    ('margen', 0.0024318461407865054),
#    ('secuestran', 0.0021415777231997102),
#    ('estructura', 0.0019564764198039984),
#    ('encargó', 0.0017504146302650229),
#    ('singular', 0.0017082420773244758),
#    ('judicial', 0.0016859719559441221),
#    ('sólidos', 0.0016454055955172121),
#    ('nombrado', 0.0016430776793915157),
#    ('acerca', 0.0016417405617366822)]),
#  (71,
#   [('realizada', 0.0027378200323658476),
#    ('construcc', 0.0026867356423461337),
#    ('consecuencia', 0.0021522946975553918),
#    ('grandes', 0.002132115657905886),
#    ('fracaso', 0.0019692173356683348),
#    ('entrega', 0.0019498730936842437),
#    ('modernización', 0.001888822092480267),
#    ('terreno', 0.0017762594479181456),
#    ('gobiernos', 0.0017539769452510382),
#    ('terminación', 0.0017154622984317182)]),
#  (72,
#   [('preparar', 0.0025155726470464201),
#    ('cuestiones', 0.0022351432909106972),
#    ('exigencia', 0.0021152495332943792),
#    ('potestad', 0.002055003878118764),
#    ('prisioneros', 0.0019502549221937467),
#    ('parís', 0.0018359699153780678),
#    ('san', 0.0016687568735179055),
#    ('estatuto', 0.0015965086892440299),
#    ('cédula', 0.001594261241981662),
#    ('presente', 0.0015852147462253913)]),
#  (73,
#   [('esfuerzo', 0.0024194035319874598),
#    ('gobiernos', 0.0023140333837942122),
#    ('parciales', 0.002014973336243113),
#    ('protagonistas', 0.0019960411141261773),
#    ('comisión', 0.0019450278192040861),
#    ('dije', 0.0017222360637484915),
#    ('secuestrado', 0.001709571060854402),
#    ('directa', 0.0016952315555832786),
#    ('octavo', 0.0016820010322245028),
#    ('próximos', 0.0016750210068174544)]),
#  (74,
#   [('reduce', 0.0029624704585426943),
#    ('moreno', 0.0022114746898119161),
#    ('décadas', 0.0021794709861173629),
#    ('miércoles', 0.0019451313879921813),
#    ('definitiva', 0.001923192490388969),
#    ('resolver', 0.0018802561644881836),
#    ('lugar', 0.0017970050488446325),
#    ('bajas', 0.001765976251756237),
#    ('vii', 0.0017574245033557363),
#    ('jurado', 0.0017496585681105244)]),
#  (75,
#   [('amable', 0.0033684160484255717),
#    ('difícil', 0.0032009133396257551),
#    ('serie', 0.0019702289912139682),
#    ('simultánea', 0.0019519453977230208),
#    ('inicio', 0.0019238134298070596),
#    ('respecto', 0.0018838169436725149),
#    ('mundo', 0.0018311295368982872),
#    ('gobiernos', 0.001739482331944335),
#    ('cerrado', 0.0017328354184125623),
#    ('sentarnos', 0.0017020178005264465)]),
#  (76,
#   [('realidad', 0.0043954035587130263),
#    ('círculo', 0.0021093888047059215),
#    ('suspender', 0.0020683741500186949),
#    ('agradecer', 0.0018639964259409734),
#    ('deuda', 0.0018634629664014742),
#    ('cascos', 0.0018619196693950403),
#    ('extensivo', 0.0018597440794774999),
#    ('búsqueda', 0.0017570446685022071),
#    ('creciendo', 0.0017225276733669986),
#    ('pedido', 0.0017124981500414697)]),
#  (77,
#   [('preparatorio', 0.0021343142490861931),
#    ('cambio', 0.0020049435809774579),
#    ('enemigos', 0.0019842706039796621),
#    ('invitación', 0.0018995141510501157),
#    ('discreta', 0.0018475895610493374),
#    ('empresa', 0.0017697733750210007),
#    ('finalmente', 0.0017344219171580909),
#    ('conservando', 0.0017122980675207961),
#    ('mantener', 0.0017047764112033458),
#    ('darán', 0.0016946187183505066)]),
#  (78,
#   [('público', 0.0030025823857876932),
#    ('efectuamos', 0.0024885702170463165),
#    ('reiteran', 0.0023106555200334221),
#    ('treinta', 0.0021332562797702409),
#    ('agradecerles', 0.0020548365006213066),
#    ('opción', 0.0019117987921663648),
#    ('afecto', 0.0018909491234031285),
#    ('temas', 0.0018688630854845646),
#    ('economía', 0.0018462808239471998),
#    ('escuchan', 0.0018015479012034885)]),
#  (79,
#   [('previa', 0.0025862268907802569),
#    ('mutua', 0.0025690969394240328),
#    ('firma', 0.0024595253266935925),
#    ('avanzando', 0.0023353831892244086),
#    ('agenda', 0.0022030236611740384),
#    ('recopilación', 0.0020908597193189798),
#    ('absoluta', 0.002001653766181857),
#    ('creen', 0.0019270867396435577),
#    ('grandes', 0.0019034468794828629),
#    ('integrales', 0.0018958099422150185)]),
#  (80,
#   [('anhelamos', 0.0026228820906506376),
#    ('hospitalidad', 0.0023862372136597707),
#    ('desarrollado', 0.0023649918344410825),
#    ('junto', 0.0023155598732013641),
#    ('ámbitos', 0.0021378201885822222),
#    ('superado', 0.00191806320724382),
#    ('reiterar', 0.0018896556098129563),
#    ('modelo', 0.0017862233113007209),
#    ('sigan', 0.0017473290319900484),
#    ('canje', 0.0017362592305781265)]),
#  (81,
#   [('momento', 0.0022518729862534607),
#    ('piensan', 0.0022150287903808905),
#    ('señores', 0.0022071852489019472),
#    ('san', 0.0020763532250283696),
#    ('terminamos', 0.0019714445390330948),
#    ('muestra', 0.0018866983843757361),
#    ('movimientos', 0.0018624857114789312),
#    ('bases', 0.001838755151064531),
#    ('ronda', 0.0018264025789769369),
#    ('plenipotenciario', 0.0017562277401020872)]),
#  (82,
#   [('mírez', 0.0023079765587691219),
#    ('hombre', 0.0023020219373846443),
#    ('ajustes', 0.0022879789440969378),
#    ('mercadeo', 0.0021858709919468479),
#    ('asistencia', 0.0021788774126141604),
#    ('cayó', 0.0020673928577511326),
#    ('precisión', 0.0020165557520151482),
#    ('sustento', 0.0019400594496474738),
#    ('convencer', 0.0018632260244968442),
#    ('alrededor', 0.0017848488547357857)]),
#  (83,
#   [('ciudadanos', 0.0021191804027973276),
#    ('modificaciones', 0.0020279345699747244),
#    ('pasando', 0.0019440518104174673),
#    ('décima', 0.0019357421008745015),
#    ('acompañarán', 0.0019075171500032486),
#    ('indica', 0.0018287129559479477),
#    ('hugo', 0.0018226384700902134),
#    ('volver', 0.0017471319238969087),
#    ('sufrieron', 0.0017061070630121392),
#    ('gobernante', 0.0016979225914242112)]),
#  (84,
#   [('camaradas', 0.0025685899364536256),
#    ('motivo', 0.0021018125722860426),
#    ('secretos', 0.0020414734808912979),
#    ('imaginar', 0.0019481180711418689),
#    ('réplica', 0.0018630315420684273),
#    ('uribe', 0.0018052822674083917),
#    ('debería', 0.0017815606373577624),
#    ('necesitan', 0.0016388852098231281),
#    ('prueba', 0.0016318127002006534),
#    ('solucionar', 0.0016275162751916623)]),
#  (85,
#   [('rueda', 0.0021730138862075909),
#    ('helicópteros', 0.0020704632722111436),
#    ('plenipotenciario', 0.0019997668276057396),
#    ('medida', 0.0018326236658460912),
#    ('trabajo', 0.0018004068416770955),
#    ('vigente', 0.001796652244594586),
#    ('coordinar', 0.0017756299831350928),
#    ('evidencia', 0.0017226701327830855),
#    ('despejes', 0.0017093379848727708),
#    ('repite', 0.001708996492509442)]),
#  (86,
#   [('bacrim', 0.0026384623222426408),
#    ('víctimas', 0.0023683051227171366),
#    ('vista', 0.0022867057583783853),
#    ('cara', 0.0019977207752520428),
#    ('nuevo', 0.0019663262077189384),
#    ('fehaciente', 0.0018409793535323522),
#    ('jefes', 0.001837555987633377),
#    ('visto', 0.0018268510988011706),
#    ('joseph', 0.0017712352573187127),
#    ('objeción', 0.001690254529760552)]),
#  (87,
#   [('aceptan', 0.0025757116298903838),
#    ('largas', 0.0025273378292596047),
#    ('martínez', 0.0019860471721091025),
#    ('administración', 0.0019484443006593289),
#    ('consejo', 0.0018795136920849668),
#    ('pierden', 0.0018409180356588198),
#    ('agentes', 0.0018294368218338007),
#    ('llevar', 0.0018269332878808249),
#    ('continente', 0.0018169713532782841),
#    ('autor', 0.0018024589801117743)]),
#  (88,
#   [('camino', 0.0026572182399480157),
#    ('riesgo', 0.0022179028189210997),
#    ('periféricas', 0.0021203845878515356),
#    ('comenzar', 0.0020689473323070012),
#    ('obstáculos', 0.0018089733958116291),
#    ('votos', 0.0017986521942913196),
#    ('condenados', 0.0017879858812835964),
#    ('igual', 0.0017793076229159419),
#    ('comunicado', 0.0017658268569296285),
#    ('preservación', 0.0017294579630936478)]),
#  (89,
#   [('sostenible', 0.0031849901612355175),
#    ('convenido', 0.0027688788161945878),
#    ('cie', 0.002448775411527525),
#    ('harán', 0.0021795921638535602),
#    ('zona', 0.0021279722444023622),
#    ('cambió', 0.0020870091689560535),
#    ('garzón', 0.0020662551906541404),
#    ('sencillamente', 0.0019717454690668483),
#    ('parcelas', 0.0019490449712966016),
#    ('cerrado', 0.0018229360559758928)]),
#  (90,
#   [('jacobo', 0.0024427553497933089),
#    ('diálogos', 0.0023939064610849006),
#    ('demasiado', 0.0022323487813559217),
#    ('unicameral', 0.0021128723232040798),
#    ('beneficios', 0.0019761960060373646),
#    ('alma', 0.001933920167597179),
#    ('mundo', 0.0018354414655033502),
#    ('contratación', 0.0017999420966471563),
#    ('bajas', 0.0017535204348359487),
#    ('institucionalidad', 0.0017419793606844865)]),
#  (91,
#   [('encargada', 0.0024252474357235264),
#    ('compromiso', 0.0019827830391590754),
#    ('partimos', 0.0018376471434532883),
#    ('digo', 0.001837159474674656),
#    ('león', 0.0018090289299236184),
#    ('dispuestos', 0.0017821616705382534),
#    ('soberanía', 0.0017467507121359817),
#    ('estudio', 0.0017412319872470883),
#    ('abiertas', 0.0017373126751953287),
#    ('convirtió', 0.001680846465568166)]),
#  (92,
#   [('debíamos', 0.0022643779548968354),
#    ('suscribe', 0.0021345735722552088),
#    ('suficientes', 0.0019998243374029848),
#    ('reconocida', 0.0019915668126086528),
#    ('partes', 0.0019776622834639401),
#    ('públicos', 0.0019595488825387506),
#    ('escribo', 0.0019272184447695372),
#    ('esfuerzo', 0.0018575556124217736),
#    ('asi', 0.001845080152200487),
#    ('seguiremos', 0.0017494066379710295)]),
#  (93,
#   [('recibido', 0.0030522216924204083),
#    ('consecución', 0.0027314900542067355),
#    ('canales', 0.0019760306925584127),
#    ('necesario', 0.0018607888440823398),
#    ('comenzamos', 0.0018544849636365156),
#    ('despojados', 0.001835664924130126),
#    ('iván', 0.0018201503125989883),
#    ('hacerlos', 0.0018158286425205765),
#    ('agradecer', 0.0017613304978202325),
#    ('señala', 0.0017026647458669014)]),
#  (94,
#   [('transformación', 0.0028834547816403442),
#    ('marcha', 0.0025702784030574178),
#    ('secretariado', 0.0024993777899405957),
#    ('logros', 0.0019134119925288073),
#    ('pueblos', 0.001837203036402224),
#    ('consulta', 0.0017812304497628849),
#    ('extender', 0.0017475288462983957),
#    ('nariño', 0.0017104311442739553),
#    ('corregimientos', 0.0017027373840315324),
#    ('lograr', 0.0016948923465222633)]),
#  (95,
#   [('exploratoria', 0.0019669027075912269),
#    ('técnico', 0.0019370591641289022),
#    ('erradicación', 0.0018261080569207402),
#    ('sanción', 0.0018251451232977872),
#    ('sola', 0.0017987322970448958),
#    ('confrontación', 0.001789684100293018),
#    ('drogas', 0.0017815739126743342),
#    ('nobel', 0.0017299004977457187),
#    ('requerir', 0.001720067489928575),
#    ('continuarán', 0.0016800080166684956)]),
#  (96,
#   [('anunciado', 0.0020984389533538592),
#    ('utilizar', 0.0020512828006969534),
#    ('estratégicas', 0.0019833341076709527),
#    ('alimentaria', 0.0019495283701476145),
#    ('campamento', 0.0019235423896873064),
#    ('obligación', 0.0019085910549828734),
#    ('pasen', 0.0018717628024027201),
#    ('julieta', 0.0018482511091731007),
#    ('solidaridad', 0.0017517067497459559),
#    ('ningún', 0.0017170180278266575)]),
#  (97,
#   [('confirma', 0.0021457173377204433),
#    ('internet', 0.0021397140971460152),
#    ('cierre', 0.0020040431892600417),
#    ('odio', 0.0019372526342717616),
#    ('espaldas', 0.0018994384557043363),
#    ('construcción', 0.0018955624760267097),
#    ('abajo', 0.0018728304468898626),
#    ('patria', 0.0018449559480700453),
#    ('representa', 0.0018127859429966555),
#    ('hecho', 0.0018074147159165871)]),
#  (98,
#   [('jurídico', 0.0025916426420341905),
#    ('internas', 0.0023008510682834427),
#    ('the', 0.0021410191565204907),
#    ('conocimiento', 0.0020984340184644363),
#    ('efectivamente', 0.0020359356792285705),
#    ('parecer', 0.0020221583051954354),
#    ('establecido', 0.0019702739910094731),
#    ('ayudaron', 0.001927360551456882),
#    ('reiteran', 0.001884123156892037),
#    ('larga', 0.0018838518743269739)]),
#  (99,
#   [('niveles', 0.0030444819322241975),
#    ('hombres', 0.0024108324504440166),
#    ('posteriormente', 0.0020347446718742171),
#    ('terminaría', 0.0019974481470706432),
#    ('terrorismo', 0.0019761387448225176),
#    ('permiten', 0.0018109833087091418),
#    ('anuncia', 0.0017632703264818684),
#    ('impulsar', 0.0017612402719979327),
#    ('colectivos', 0.0017438433376781844),
#    ('sistemas', 0.0017218744652087617)])]

# %% [markdown]
# #### Association document-topics

# %%
corpus = hdp_best_topics[1][2]
for doc in corpus:
    print(doc)
# Out:
# [(12, 0.9982108900405563)]
# [(2, 0.99961348842383657)]
# [(26, 0.99142230968466494)]
# [(0, 0.9996518433846785)]
# [(0, 0.89715709430113677), (1, 0.099494712319693437)]
# [(8, 0.99912483862812485)]
# [(22, 0.99434558515896632)]
# [(0, 0.99802454979367861)]
# [(1, 0.99964994992828582)]
# [(15, 0.99804615975468725)]
# [(29, 0.99035525672952196)]
# [(16, 0.9969028261701578)]
# [(17, 0.99685575005364735)]
# [(23, 0.99240447174089108)]
# [(4, 0.99931056173366384)]
# [(9, 0.82657819079915429), (14, 0.16998285134874885)]
# [(20, 0.9968564286411804)]
# [(19, 0.9963528270119385)]
# [(14, 0.9980449148040289)]
# [(6, 0.99926037152639569)]
# [(7, 0.99916415781389278)]
# [(11, 0.99881707897653127)]
# [(24, 0.99070659833138441)]
# [(10, 0.99907388799799945)]
# [(1, 0.17869457540427702), (10, 0.81934901816722061)]
# [(18, 0.99656662112623118)]
# [(3, 0.99836908159405346)]
# [(9, 0.99872933470312686)]
# [(5, 0.99927352528591651)]
# [(3, 0.99935220510323264)]
# [(25, 0.98588484083552275)]
# [(21, 0.99685170760359054)]
# [(0, 0.99963863470644854)]
# [(13, 0.99819847465909206)]
# [(0, 0.99833711591019181)]

# %% [markdown]
# #### Topics sorted by recurrence

# %%
total_weights = defaultdict(float)
for doc in corpus:
    for topic, weight in doc:
        total_weights[topic] += abs(weight)
total_weights = dict(total_weights)

# %%
Counter(total_weights).most_common()
# Out:
# [(0, 4.8928092380961345),
#  (3, 1.9977212866972862),
#  (9, 1.8253075255022813),
#  (10, 1.8184229061652202),
#  (1, 1.2778392376522563),
#  (14, 1.1680277661527778),
#  (2, 0.99961348842383657),
#  (4, 0.99931056173366384),
#  (5, 0.99927352528591651),
#  (6, 0.99926037152639569),
#  (7, 0.99916415781389278),
#  (8, 0.99912483862812485),
#  (11, 0.99881707897653127),
#  (12, 0.9982108900405563),
#  (13, 0.99819847465909206),
#  (15, 0.99804615975468725),
#  (16, 0.9969028261701578),
#  (20, 0.9968564286411804),
#  (17, 0.99685575005364735),
#  (21, 0.99685170760359054),
#  (18, 0.99656662112623118),
#  (19, 0.9963528270119385),
#  (22, 0.99434558515896632),
#  (23, 0.99240447174089108),
#  (26, 0.99142230968466494),
#  (24, 0.99070659833138441),
#  (29, 0.99035525672952196),
#  (25, 0.98588484083552275)]
